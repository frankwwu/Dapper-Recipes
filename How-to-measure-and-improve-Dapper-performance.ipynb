# %% [markdown]
# # How to measure and improve Dapper performance
#
# To measure and improve Dapper performance with C#, you can use the following steps:
#
# - Install the Dapper and BenchmarkDotNet in your project.
# - Create a class that implements the <code>IBenchmark</code> interface and defines the methods for setting up, executing, and cleaning up the benchmark.
# - Create a connection to the AdventureWorks2022 database using the <code>SqlConnection</code> class and the connection string.
# - In the execute method, use the <code>Query</code> extension method of Dapper to execute a SQL query and map the results to a C# object. For example, you can query the Product table and map the results to a Product class.
# - In the cleanup method, dispose the connection object and release any resources used by the benchmark.
# - Use the <code>BenchmarkRunner</code> class to run the benchmark and generate a report that shows the performance metrics such as mean time, standard deviation, allocations, etc.
# - To improve the performance of Dapper, you can try some of the following tips:
#     * Use parameterized queries instead of string concatenation or interpolation to avoid SQL injection and improve query plan caching.
#     * Use the <code>Buffered</code> parameter of the <code>Query</code> method to control whether the results are buffered in memory or streamed from the database. Buffering can improve performance for small result sets, but streaming can reduce memory usage for large result sets.
#     * Use the <code>SplitOn</code> parameter of the <code>Query</code> method to specify the column name that separates the objects in a multi-mapping query. This can avoid unnecessary reflection and improve mapping speed.
#     * Use the <code>AsNoTracking</code> extension method of EF Core to disable change tracking and improve query performance when you only need to read data from the database.

# %% [markdown]
# Here is a C# example of how to use BenchmarkRunner with Dapper. It assumes that you have installed the Dapper and BenchmarkDotNet NuGet packages, and that you have a connection string to the AdventureWorks2022 database. The example benchmarks two methods that query the Product table using different approaches: one using raw SQL and the other using stored procedure. The results are printed to the console and exported to a markdown file.

# %%
// Connection string
#load "AppSettings.cs"

# %%
#r "nuget:Dapper"
#r "nuget:BenchmarkDotNet"
#r "nuget:Microsoft.Data.SqlClient"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>BenchmarkDotNet, 0.13.12</span></li><li><span>Dapper, 2.1.28</span></li><li><span>Microsoft.Data.SqlClient, 5.1.5</span></li></ul></div></div>

# %%
using System;
using System.Data;
using Microsoft.Data.SqlClient;
using BenchmarkDotNet.Attributes;
using BenchmarkDotNet.Running;
using Dapper;

public class Product
{
    public int ProductID { get; set; }
    public string Name { get; set; }
    public decimal ListPrice { get; set; }
}

public class DapperBenchmarks
{   
    private const string sqlQuery = "SELECT ProductID, Name, ListPrice FROM Production.Product WHERE ListPrice > 3000";
    private const string storedProcedure = "uspGetProducts";

    [Benchmark]
    public Product[] QueryWithSql()
    {
        using (var connection = new SqlConnection(connectionString))
        {
            return connection.Query<Product>(sqlQuery).ToArray();
        }
    }

    [Benchmark]
    public Product[] QueryWithStoredProcedure()
    {
        using (var connection = new SqlConnection(connectionString))
        {
            return connection.Query<Product>(storedProcedure, commandType: System.Data.CommandType.StoredProcedure).ToArray();
        }
    }
}

# %%
var summary = BenchmarkRunner.Run<DapperBenchmarks>(new BenchmarkDotNet.Configs.DebugInProcessConfig());
Console.WriteLine($"An invalid operation occurred: {summary}");
# Out:
# ]9;4;3;0\// Validating benchmarks:
# //    * No exporters defined, results will not be persisted.
#
# // ***** BenchmarkRunner: Start   *****
# // ***** Found 2 benchmark(s) in total *****
# // ***** Building 1 exe(s) in Parallel: Start   *****
# // ***** Done, took 00:00:00 (0.03 sec)   *****
# // Found 2 benchmarks:
# //   DapperBenchmarks.QueryWithSql: Job-IJHYBO(Toolchain=InProcessEmitToolchain)
# //   DapperBenchmarks.QueryWithStoredProcedure: Job-IJHYBO(Toolchain=InProcessEmitToolchain)
#
# Setup power plan (GUID: 8c5e7fda-e8bf-4a96-9a85-a6e23a8c635c FriendlyName: High performance)
# // **************************
# // Benchmark: DapperBenchmarks.QueryWithSql: Job-IJHYBO(Toolchain=InProcessEmitToolchain)
# // *** Execute ***
# // Launch: 1 / 1
#
# // Benchmark Process Environment Information:
# // BenchmarkDotNet v0.13.12
# // Runtime=.NET 8.0.1 (8.0.123.58001), X64 RyuJIT AVX-512F+CD+BW+DQ+VL+VBMI
# // GC=Concurrent Server
# // HardwareIntrinsics=AVX-512F+CD+BW+DQ+VL+VBMI,AES,BMI1,BMI2,FMA,LZCNT,PCLMUL,POPCNT VectorSize=256
# // Job: Job-IJHYBO(Toolchain=InProcessEmitToolchain)
#
# OverheadJitting  1: 1 op, 340400.00 ns, 340.4000 us/op
# WorkloadJitting  1: 1 op, 192187200.00 ns, 192.1872 ms/op
#
# WorkloadPilot    1: 2 op, 4980400.00 ns, 2.4902 ms/op
# WorkloadPilot    2: 3 op, 2476500.00 ns, 825.5000 us/op
# WorkloadPilot    3: 4 op, 4051100.00 ns, 1.0128 ms/op
# WorkloadPilot    4: 5 op, 4347100.00 ns, 869.4200 us/op
# WorkloadPilot    5: 6 op, 16233100.00 ns, 2.7055 ms/op
# WorkloadPilot    6: 7 op, 6264800.00 ns, 894.9714 us/op
# WorkloadPilot    7: 8 op, 7206500.00 ns, 900.8125 us/op
# WorkloadPilot    8: 9 op, 7129400.00 ns, 792.1556 us/op
# WorkloadPilot    9: 10 op, 8360500.00 ns, 836.0500 us/op
# WorkloadPilot   10: 11 op, 7159000.00 ns, 650.8182 us/op
# WorkloadPilot   11: 12 op, 5623500.00 ns, 468.6250 us/op
# WorkloadPilot   12: 13 op, 6559100.00 ns, 504.5462 us/op
# WorkloadPilot   13: 14 op, 6491000.00 ns, 463.6429 us/op
# WorkloadPilot   14: 15 op, 6754100.00 ns, 450.2733 us/op
# WorkloadPilot   15: 16 op, 10433600.00 ns, 652.1000 us/op
# WorkloadPilot   16: 32 op, 14497900.00 ns, 453.0594 us/op
# WorkloadPilot   17: 64 op, 24284600.00 ns, 379.4469 us/op
# WorkloadPilot   18: 128 op, 37900500.00 ns, 296.0977 us/op
# WorkloadPilot   19: 256 op, 67182700.00 ns, 262.4324 us/op
# WorkloadPilot   20: 512 op, 143503500.00 ns, 280.2803 us/op
# WorkloadPilot   21: 1024 op, 265581900.00 ns, 259.3573 us/op
# WorkloadPilot   22: 2048 op, 539978700.00 ns, 263.6615 us/op
#
# WorkloadWarmup   1: 2048 op, 554807500.00 ns, 270.9021 us/op
# WorkloadWarmup   2: 2048 op, 422072800.00 ns, 206.0902 us/op
# WorkloadWarmup   3: 2048 op, 441362500.00 ns, 215.5090 us/op
# WorkloadWarmup   4: 2048 op, 465258000.00 ns, 227.1768 us/op
# WorkloadWarmup   5: 2048 op, 464754100.00 ns, 226.9307 us/op
# WorkloadWarmup   6: 2048 op, 459840400.00 ns, 224.5314 us/op
# WorkloadWarmup   7: 2048 op, 486757000.00 ns, 237.6743 us/op
# WorkloadWarmup   8: 2048 op, 495741300.00 ns, 242.0612 us/op
# WorkloadWarmup   9: 2048 op, 469420500.00 ns, 229.2092 us/op
#
# WorkloadActual   1: 2048 op, 481804000.00 ns, 235.2559 us/op
# WorkloadActual   2: 2048 op, 481080400.00 ns, 234.9025 us/op
# WorkloadActual   3: 2048 op, 468736200.00 ns, 228.8751 us/op
# WorkloadActual   4: 2048 op, 449080900.00 ns, 219.2778 us/op
# WorkloadActual   5: 2048 op, 424201100.00 ns, 207.1294 us/op
# WorkloadActual   6: 2048 op, 418108700.00 ns, 204.1546 us/op
# WorkloadActual   7: 2048 op, 387855300.00 ns, 189.3825 us/op
# WorkloadActual   8: 2048 op, 410980400.00 ns, 200.6740 us/op
# WorkloadActual   9: 2048 op, 394545700.00 ns, 192.6493 us/op
# WorkloadActual  10: 2048 op, 395242700.00 ns, 192.9896 us/op
# WorkloadActual  11: 2048 op, 389142100.00 ns, 190.0108 us/op
# WorkloadActual  12: 2048 op, 398756300.00 ns, 194.7052 us/op
# WorkloadActual  13: 2048 op, 393149400.00 ns, 191.9675 us/op
# WorkloadActual  14: 2048 op, 395894100.00 ns, 193.3077 us/op
# WorkloadActual  15: 2048 op, 389819400.00 ns, 190.3415 us/op
# WorkloadActual  16: 2048 op, 397863700.00 ns, 194.2694 us/op
# WorkloadActual  17: 2048 op, 406493600.00 ns, 198.4832 us/op
# WorkloadActual  18: 2048 op, 415233500.00 ns, 202.7507 us/op
# WorkloadActual  19: 2048 op, 401762600.00 ns, 196.1731 us/op
# WorkloadActual  20: 2048 op, 392167400.00 ns, 191.4880 us/op
# WorkloadActual  21: 2048 op, 457237400.00 ns, 223.2604 us/op
# WorkloadActual  22: 2048 op, 405112900.00 ns, 197.8090 us/op
# WorkloadActual  23: 2048 op, 384345300.00 ns, 187.6686 us/op
# WorkloadActual  24: 2048 op, 394806600.00 ns, 192.7767 us/op
# WorkloadActual  25: 2048 op, 391810400.00 ns, 191.3137 us/op
# WorkloadActual  26: 2048 op, 390306200.00 ns, 190.5792 us/op
# WorkloadActual  27: 2048 op, 390864500.00 ns, 190.8518 us/op
# WorkloadActual  28: 2048 op, 388752400.00 ns, 189.8205 us/op
# WorkloadActual  29: 2048 op, 390048800.00 ns, 190.4535 us/op
# WorkloadActual  30: 2048 op, 380307700.00 ns, 185.6971 us/op
# WorkloadActual  31: 2048 op, 397293000.00 ns, 193.9907 us/op
#
# WorkloadResult   1: 2048 op, 424201100.00 ns, 207.1294 us/op
# WorkloadResult   2: 2048 op, 418108700.00 ns, 204.1546 us/op
# WorkloadResult   3: 2048 op, 387855300.00 ns, 189.3825 us/op
# WorkloadResult   4: 2048 op, 410980400.00 ns, 200.6740 us/op
# WorkloadResult   5: 2048 op, 394545700.00 ns, 192.6493 us/op
# WorkloadResult   6: 2048 op, 395242700.00 ns, 192.9896 us/op
# WorkloadResult   7: 2048 op, 389142100.00 ns, 190.0108 us/op
# WorkloadResult   8: 2048 op, 398756300.00 ns, 194.7052 us/op
# WorkloadResult   9: 2048 op, 393149400.00 ns, 191.9675 us/op
# WorkloadResult  10: 2048 op, 395894100.00 ns, 193.3077 us/op
# WorkloadResult  11: 2048 op, 389819400.00 ns, 190.3415 us/op
# WorkloadResult  12: 2048 op, 397863700.00 ns, 194.2694 us/op
# WorkloadResult  13: 2048 op, 406493600.00 ns, 198.4832 us/op
# WorkloadResult  14: 2048 op, 415233500.00 ns, 202.7507 us/op
# WorkloadResult  15: 2048 op, 401762600.00 ns, 196.1731 us/op
# WorkloadResult  16: 2048 op, 392167400.00 ns, 191.4880 us/op
# WorkloadResult  17: 2048 op, 405112900.00 ns, 197.8090 us/op
# WorkloadResult  18: 2048 op, 384345300.00 ns, 187.6686 us/op
# WorkloadResult  19: 2048 op, 394806600.00 ns, 192.7767 us/op
# WorkloadResult  20: 2048 op, 391810400.00 ns, 191.3137 us/op
# WorkloadResult  21: 2048 op, 390306200.00 ns, 190.5792 us/op
# WorkloadResult  22: 2048 op, 390864500.00 ns, 190.8518 us/op
# WorkloadResult  23: 2048 op, 388752400.00 ns, 189.8205 us/op
# WorkloadResult  24: 2048 op, 390048800.00 ns, 190.4535 us/op
# WorkloadResult  25: 2048 op, 380307700.00 ns, 185.6971 us/op
# WorkloadResult  26: 2048 op, 397293000.00 ns, 193.9907 us/op
#
#
# Mean = 193.901 us, StdErr = 1.015 us (0.52%), N = 26, StdDev = 5.177 us
# Min = 185.697 us, Q1 = 190.485 us, Median = 192.713 us, Q3 = 195.806 us, Max = 207.129 us
# IQR = 5.321 us, LowerFence = 182.503 us, UpperFence = 203.788 us
# ConfidenceInterval = [190.119 us; 197.684 us] (CI 99.9%), Margin = 3.782 us (1.95% of Mean)
# Skewness = 0.93, Kurtosis = 3.12, MValue = 2
#
# // ** Remained 1 (50.0%) benchmark(s) to run. Estimated finish 2024-01-30 8:26 (0h 0m from now) **
# ]9;4;1;50\Setup power plan (GUID: 8c5e7fda-e8bf-4a96-9a85-a6e23a8c635c FriendlyName: High performance)
# // **************************
# // Benchmark: DapperBenchmarks.QueryWithStoredProcedure: Job-IJHYBO(Toolchain=InProcessEmitToolchain)
# // *** Execute ***
# // Launch: 1 / 1
#
# // Benchmark Process Environment Information:
# // BenchmarkDotNet v0.13.12
# // Runtime=.NET 8.0.1 (8.0.123.58001), X64 RyuJIT AVX-512F+CD+BW+DQ+VL+VBMI
# // GC=Concurrent Server
# // HardwareIntrinsics=AVX-512F+CD+BW+DQ+VL+VBMI,AES,BMI1,BMI2,FMA,LZCNT,PCLMUL,POPCNT VectorSize=256
# // Job: Job-IJHYBO(Toolchain=InProcessEmitToolchain)
#
# OverheadJitting  1: 1 op, 310100.00 ns, 310.1000 us/op
#
# System.Reflection.TargetInvocationException: Exception has been thrown by the target of an invocation.
#  ---> Microsoft.Data.SqlClient.SqlException (0x80131904): Could not find stored procedure 'uspGetProducts'.
#    at Microsoft.Data.SqlClient.SqlConnection.OnError(SqlException exception, Boolean breakConnection, Action`1 wrapCloseInAction) in /_/src/Microsoft.Data.SqlClient/netcore/src/Microsoft/Data/SqlClient/SqlConnection.cs:line 2010
#    at Microsoft.Data.SqlClient.SqlInternalConnection.OnError(SqlException exception, Boolean breakConnection, Action`1 wrapCloseInAction) in /_/src/Microsoft.Data.SqlClient/src/Microsoft/Data/SqlClient/SqlInternalConnection.cs:line 770
#    at Microsoft.Data.SqlClient.TdsParser.ThrowExceptionAndWarning(TdsParserStateObject stateObj, Boolean callerHasConnectionLock, Boolean asyncClose) in /_/src/Microsoft.Data.SqlClient/netcore/src/Microsoft/Data/SqlClient/TdsParser.cs:line 1421
#    at Microsoft.Data.SqlClient.TdsParser.TryRun(RunBehavior runBehavior, SqlCommand cmdHandler, SqlDataReader dataStream, BulkCopySimpleResultSet bulkCopyHandler, TdsParserStateObject stateObj, Boolean& dataReady) in /_/src/Microsoft.Data.SqlClient/netcore/src/Microsoft/Data/SqlClient/TdsParser.cs:line 2637
#    at Microsoft.Data.SqlClient.SqlDataReader.TryConsumeMetaData() in /_/src/Microsoft.Data.SqlClient/netcore/src/Microsoft/Data/SqlClient/SqlDataReader.cs:line 1142
#    at Microsoft.Data.SqlClient.SqlCommand.FinishExecuteReader(SqlDataReader ds, RunBehavior runBehavior, String resetOptionsString, Boolean isInternal, Boolean forDescribeParameterEncryption, Boolean shouldCacheForAlwaysEncrypted) in /_/src/Microsoft.Data.SqlClient/netcore/src/Microsoft/Data/SqlClient/SqlCommand.cs:line 5171
#    at Microsoft.Data.SqlClient.SqlCommand.RunExecuteReaderTds(CommandBehavior cmdBehavior, RunBehavior runBehavior, Boolean returnStream, Boolean isAsync, Int32 timeout, Task& task, Boolean asyncWrite, Boolean inRetry, SqlDataReader ds, Boolean describeParameterEncryptionRequest) in /_/src/Microsoft.Data.SqlClient/netcore/src/Microsoft/Data/SqlClient/SqlCommand.cs:line 4984
#    at Microsoft.Data.SqlClient.SqlCommand.RunExecuteReader(CommandBehavior cmdBehavior, RunBehavior runBehavior, Boolean returnStream, TaskCompletionSource`1 completion, Int32 timeout, Task& task, Boolean& usedCache, Boolean asyncWrite, Boolean inRetry, String method) in /_/src/Microsoft.Data.SqlClient/netcore/src/Microsoft/Data/SqlClient/SqlCommand.cs:line 4663
#    at Microsoft.Data.SqlClient.SqlCommand.ExecuteReader(CommandBehavior behavior) in /_/src/Microsoft.Data.SqlClient/netcore/src/Microsoft/Data/SqlClient/SqlCommand.cs:line 2043
#    at Dapper.SqlMapper.ExecuteReaderWithFlagsFallback(IDbCommand cmd, Boolean wasClosed, CommandBehavior behavior) in /_/Dapper/SqlMapper.cs:line 1156
#    at Dapper.SqlMapper.QueryImpl[T](IDbConnection cnn, CommandDefinition command, Type effectiveType)+MoveNext() in /_/Dapper/SqlMapper.cs:line 1184
#    at System.Collections.Generic.List`1..ctor(IEnumerable`1 collection)
#    at System.Linq.Enumerable.ToList[TSource](IEnumerable`1 source)
#    at Dapper.SqlMapper.Query[T](IDbConnection cnn, String sql, Object param, IDbTransaction transaction, Boolean buffered, Nullable`1 commandTimeout, Nullable`1 commandType) in /_/Dapper/SqlMapper.cs:line 815
#    at Submission#3.DapperBenchmarks.QueryWithStoredProcedure()
#    at BenchmarkDotNet.Autogenerated.Runnable_1.WorkloadActionNoUnroll(Int64 invokeCount)
#    at BenchmarkDotNet.Engines.Engine.RunIteration(IterationData data)
#    at BenchmarkDotNet.Engines.EngineFactory.Jit(Engine engine, Int32 jitIndex, Int32 invokeCount, Int32 unrollFactor)
#    at BenchmarkDotNet.Engines.EngineFactory.CreateReadyToRun(EngineParameters engineParameters)
#    at BenchmarkDotNet.Autogenerated.Runnable_1.Run(BenchmarkCase benchmarkCase, IHost host)
#    at System.RuntimeMethodHandle.InvokeMethod(Object target, Void** arguments, Signature sig, Boolean isConstructor)
#    at System.Reflection.MethodBaseInvoker.InvokeDirectByRefWithFewArgs(Object obj, Span`1 copyOfArgs, BindingFlags invokeAttr)
# ClientConnectionId:6c6e35b0-2aa9-4b21-ba0b-a79d10b7655e
# Error Number:2812,State:62,Class:16
#    --- End of inner exception stack trace ---
#    at System.Reflection.MethodBaseInvoker.InvokeDirectByRefWithFewArgs(Object obj, Span`1 copyOfArgs, BindingFlags invokeAttr)
#    at System.Reflection.MethodBaseInvoker.InvokeWithFewArgs(Object obj, BindingFlags invokeAttr, Binder binder, Object[] parameters, CultureInfo culture)
#    at System.Reflection.MethodBase.Invoke(Object obj, Object[] parameters)
#    at BenchmarkDotNet.Toolchains.InProcess.Emit.Implementation.RunnableProgram.Run(BenchmarkId benchmarkId, Assembly partitionAssembly, BenchmarkCase benchmarkCase, IHost host)
# Executable C:\Users\frank\.nuget\packages\microsoft.dotnet-interactive\1.0.507501\tools\net8.0\any\Job-IJHYBOEmitted.dll not found
# ExitCode != 0 and no results reported
# No Workload Results were obtained from the run.
#
# // ** Remained 0 (0.0%) benchmark(s) to run. Estimated finish 2024-01-30 8:26 (0h 0m from now) **
# ]9;4;1;100\Successfully reverted power plan (GUID: 381b4222-f694-41f0-9685-ff5bb260df2e FriendlyName: Balanced)
# // ***** BenchmarkRunner: Finish  *****
#
# // * Export *
#
# // * Detailed results *
# DapperBenchmarks.QueryWithSql: Job-IJHYBO(Toolchain=InProcessEmitToolchain)
# Runtime = ; GC =
# Mean = 193.901 us, StdErr = 1.015 us (0.52%), N = 26, StdDev = 5.177 us
# Min = 185.697 us, Q1 = 190.485 us, Median = 192.713 us, Q3 = 195.806 us, Max = 207.129 us
# IQR = 5.321 us, LowerFence = 182.503 us, UpperFence = 203.788 us
# ConfidenceInterval = [190.119 us; 197.684 us] (CI 99.9%), Margin = 3.782 us (1.95% of Mean)
# Skewness = 0.93, Kurtosis = 3.12, MValue = 2
# -------------------- Histogram --------------------
# [185.246 us ; 189.751 us) | @@@
# [189.751 us ; 194.339 us) | @@@@@@@@@@@@@@@
# [194.339 us ; 200.121 us) | @@@@
# [200.121 us ; 204.708 us) | @@@
# [204.708 us ; 209.423 us) | @
# ---------------------------------------------------
#
# DapperBenchmarks.QueryWithStoredProcedure: Job-IJHYBO(Toolchain=InProcessEmitToolchain)
# Runtime = ; GC =
# There are not any results runs
#
# // * Summary *
#
# BenchmarkDotNet v0.13.12, Windows 11 (10.0.22631.3085/23H2/2023Update/SunValley3)
# 11th Gen Intel Core i7-11800H 2.30GHz, 1 CPU, 16 logical and 8 physical cores
# .NET SDK 8.0.101
#   [Host] : .NET 8.0.1 (8.0.123.58001), X64 RyuJIT AVX-512F+CD+BW+DQ+VL+VBMI
#
# Toolchain=InProcessEmitToolchain
#
# | Method                   | Mean     | Error   | StdDev  |
# |------------------------- |---------:|--------:|--------:|
# | QueryWithSql             | 193.9 us | 3.78 us | 5.18 us |
# | QueryWithStoredProcedure |       NA |      NA |      NA |
#
# Benchmarks with issues:
#   DapperBenchmarks.QueryWithStoredProcedure: Job-IJHYBO(Toolchain=InProcessEmitToolchain)
#
# // * Legends *
#   Mean   : Arithmetic mean of all measurements
#   Error  : Half of 99.9% confidence interval
#   StdDev : Standard deviation of all measurements
#   1 us   : 1 Microsecond (0.000001 sec)
#
# // ***** BenchmarkRunner: End *****
# Run time: 00:00:20 (20.73 sec), executed benchmarks: 1
#
# Global total time: 00:00:21 (21.09 sec), executed benchmarks: 1
# // * Artifacts cleanup *
# Artifacts cleanup is finished
# ]9;4;0;0\An invalid operation occurred: BenchmarkDotNet.Reports.Summary

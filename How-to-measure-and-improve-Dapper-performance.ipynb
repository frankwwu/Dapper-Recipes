# %% [markdown]
# # How to measure and improve Dapper performance
#
# To measure and improve Dapper performance with C#, you can use the following steps:
#
# - Install the Dapper and BenchmarkDotNet in your project.
# - Create a class that implements the <code>IBenchmark</code> interface and defines the methods for setting up, executing, and cleaning up the benchmark.
# - Create a connection to the AdventureWorks2022 database using the <code>SqlConnection</code> class and the connection string.
# - In the execute method, use the <code>Query</code> extension method of Dapper to execute a SQL query and map the results to a C# object. For example, you can query the Product table and map the results to a Product class.
# - In the cleanup method, dispose the connection object and release any resources used by the benchmark.
# - Use the <code>BenchmarkRunner</code> class to run the benchmark and generate a report that shows the performance metrics such as mean time, standard deviation, allocations, etc.
# - To improve the performance of Dapper, you can try some of the following tips:
#     * Use parameterized queries instead of string concatenation or interpolation to avoid SQL injection and improve query plan caching.
#     * Use the <code>Buffered</code> parameter of the <code>Query</code> method to control whether the results are buffered in memory or streamed from the database. Buffering can improve performance for small result sets, but streaming can reduce memory usage for large result sets.
#     * Use the <code>SplitOn</code> parameter of the <code>Query</code> method to specify the column name that separates the objects in a multi-mapping query. This can avoid unnecessary reflection and improve mapping speed.
#     * Use the <code>AsNoTracking</code> extension method of EF Core to disable change tracking and improve query performance when you only need to read data from the database.

# %% [markdown]
# Here is a C# example of how to use <code>BenchmarkRunner</code> with Dapper. It assumes that you have installed the Dapper and BenchmarkDotNet NuGet packages, and that you have a connection string to the AdventureWorks2022 database. The example benchmarks two methods that query the Product table using different approaches: one using raw SQL and the other using stored procedure. The results are printed to the console and exported to a markdown file.

# %%
// Connection string
#load "AppSettings.cs"

# %%
#r "nuget:Dapper"
#r "nuget:BenchmarkDotNet"
#r "nuget:Microsoft.Data.SqlClient"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>BenchmarkDotNet, 0.13.12</span></li><li><span>Dapper, 2.1.28</span></li><li><span>Microsoft.Data.SqlClient, 5.1.5</span></li></ul></div></div>

# %%
using System;
using System.Data;
using Microsoft.Data.SqlClient;
using BenchmarkDotNet.Attributes;
using BenchmarkDotNet.Running;
using BenchmarkDotNet.Configs;
using Dapper;

# %%
public class Product
{
    public int ProductID { get; set; }
    public string Name { get; set; }
    public decimal ListPrice { get; set; }
}

public class Employee
{
    public int BusinessEntityID { get; set; }
    public int RecursionLevel { get; set; }   
    public string FirstName { get; set; }
    public string LastName { get; set; }
    public string ManagerFirstName { get; set; }
    public string ManagerLastName { get; set; }
}

# %%
public class DapperBenchmarks
{   
    private const string sqlQuery = "SELECT ProductID, Name, ListPrice FROM Production.Product WHERE ListPrice > 3000";
    private const string storedProcedure = "uspGetEmployeeManagers";

    [Benchmark]
    public Product[] SqlQuery()
    {
        using (var connection = new SqlConnection(connectionString))
        {
            return connection.Query<Product>(sqlQuery).ToArray();
        }
    }

    [Benchmark]
    public Employee[] StoredProcedure()
    {
        using (var connection = new SqlConnection(connectionString))
        {
            DynamicParameters parameters = new DynamicParameters();
            parameters.Add("@BusinessEntityID", 12);           
            return connection.Query<Employee>(storedProcedure, parameters, commandType: CommandType.StoredProcedure).ToArray();
        }
    }
}

# %%
var summary = BenchmarkRunner.Run<DapperBenchmarks>(new DebugInProcessConfig());
Console.WriteLine(summary);
# Out:
# ]9;4;3;0\// Validating benchmarks:
# //    * No exporters defined, results will not be persisted.
#
# // ***** BenchmarkRunner: Start   *****
# // ***** Found 2 benchmark(s) in total *****
# // ***** Building 1 exe(s) in Parallel: Start   *****
# // ***** Done, took 00:00:00 (0.03 sec)   *****
# // Found 2 benchmarks:
# //   DapperBenchmarks.SqlQuery: Job-BQHOSZ(Toolchain=InProcessEmitToolchain)
# //   DapperBenchmarks.StoredProcedure: Job-BQHOSZ(Toolchain=InProcessEmitToolchain)
#
# Setup power plan (GUID: 8c5e7fda-e8bf-4a96-9a85-a6e23a8c635c FriendlyName: High performance)
# // **************************
# // Benchmark: DapperBenchmarks.SqlQuery: Job-BQHOSZ(Toolchain=InProcessEmitToolchain)
# // *** Execute ***
# // Launch: 1 / 1
#
# // Benchmark Process Environment Information:
# // BenchmarkDotNet v0.13.12
# // Runtime=.NET 8.0.1 (8.0.123.58001), X64 RyuJIT AVX-512F+CD+BW+DQ+VL+VBMI
# // GC=Concurrent Server
# // HardwareIntrinsics=AVX-512F+CD+BW+DQ+VL+VBMI,AES,BMI1,BMI2,FMA,LZCNT,PCLMUL,POPCNT VectorSize=256
# // Job: Job-BQHOSZ(Toolchain=InProcessEmitToolchain)
#
# OverheadJitting  1: 1 op, 258400.00 ns, 258.4000 us/op
# WorkloadJitting  1: 1 op, 197154100.00 ns, 197.1541 ms/op
#
# WorkloadPilot    1: 2 op, 3625200.00 ns, 1.8126 ms/op
# WorkloadPilot    2: 3 op, 3172800.00 ns, 1.0576 ms/op
# WorkloadPilot    3: 4 op, 3591400.00 ns, 897.8500 us/op
# WorkloadPilot    4: 5 op, 4280700.00 ns, 856.1400 us/op
# WorkloadPilot    5: 6 op, 5042900.00 ns, 840.4833 us/op
# WorkloadPilot    6: 7 op, 5289000.00 ns, 755.5714 us/op
# WorkloadPilot    7: 8 op, 5798400.00 ns, 724.8000 us/op
# WorkloadPilot    8: 9 op, 6333900.00 ns, 703.7667 us/op
# WorkloadPilot    9: 10 op, 7425600.00 ns, 742.5600 us/op
# WorkloadPilot   10: 11 op, 5922500.00 ns, 538.4091 us/op
# WorkloadPilot   11: 12 op, 5680300.00 ns, 473.3583 us/op
# WorkloadPilot   12: 13 op, 43013000.00 ns, 3.3087 ms/op
# WorkloadPilot   13: 14 op, 38250000.00 ns, 2.7321 ms/op
# WorkloadPilot   14: 15 op, 33578900.00 ns, 2.2386 ms/op
# WorkloadPilot   15: 16 op, 9348500.00 ns, 584.2812 us/op
# WorkloadPilot   16: 32 op, 15087700.00 ns, 471.4906 us/op
# WorkloadPilot   17: 64 op, 19595600.00 ns, 306.1812 us/op
# WorkloadPilot   18: 128 op, 31246900.00 ns, 244.1164 us/op
# WorkloadPilot   19: 256 op, 80953900.00 ns, 316.2262 us/op
# WorkloadPilot   20: 512 op, 151622700.00 ns, 296.1381 us/op
# WorkloadPilot   21: 1024 op, 283630900.00 ns, 276.9833 us/op
# WorkloadPilot   22: 2048 op, 661241500.00 ns, 322.8718 us/op
#
# WorkloadWarmup   1: 2048 op, 423934100.00 ns, 206.9991 us/op
# WorkloadWarmup   2: 2048 op, 411034400.00 ns, 200.7004 us/op
# WorkloadWarmup   3: 2048 op, 409673800.00 ns, 200.0360 us/op
# WorkloadWarmup   4: 2048 op, 403141000.00 ns, 196.8462 us/op
# WorkloadWarmup   5: 2048 op, 1165266800.00 ns, 568.9779 us/op
# WorkloadWarmup   6: 2048 op, 463441800.00 ns, 226.2899 us/op
# WorkloadWarmup   7: 2048 op, 750009700.00 ns, 366.2157 us/op
# WorkloadWarmup   8: 2048 op, 540730200.00 ns, 264.0284 us/op
#
# WorkloadActual   1: 2048 op, 453551000.00 ns, 221.4604 us/op
# WorkloadActual   2: 2048 op, 515685500.00 ns, 251.7996 us/op
# WorkloadActual   3: 2048 op, 447202400.00 ns, 218.3605 us/op
# WorkloadActual   4: 2048 op, 537473100.00 ns, 262.4380 us/op
# WorkloadActual   5: 2048 op, 536852200.00 ns, 262.1349 us/op
# WorkloadActual   6: 2048 op, 433300200.00 ns, 211.5724 us/op
# WorkloadActual   7: 2048 op, 426571900.00 ns, 208.2871 us/op
# WorkloadActual   8: 2048 op, 517992100.00 ns, 252.9258 us/op
# WorkloadActual   9: 2048 op, 411235900.00 ns, 200.7988 us/op
# WorkloadActual  10: 2048 op, 412233700.00 ns, 201.2860 us/op
# WorkloadActual  11: 2048 op, 425642500.00 ns, 207.8333 us/op
# WorkloadActual  12: 2048 op, 447374700.00 ns, 218.4447 us/op
# WorkloadActual  13: 2048 op, 414608600.00 ns, 202.4456 us/op
# WorkloadActual  14: 2048 op, 455867500.00 ns, 222.5916 us/op
# WorkloadActual  15: 2048 op, 437279600.00 ns, 213.5154 us/op
# WorkloadActual  16: 2048 op, 426623400.00 ns, 208.3122 us/op
# WorkloadActual  17: 2048 op, 406712600.00 ns, 198.5901 us/op
# WorkloadActual  18: 2048 op, 410155500.00 ns, 200.2712 us/op
# WorkloadActual  19: 2048 op, 412826700.00 ns, 201.5755 us/op
# WorkloadActual  20: 2048 op, 411572400.00 ns, 200.9631 us/op
# WorkloadActual  21: 2048 op, 404649400.00 ns, 197.5827 us/op
# WorkloadActual  22: 2048 op, 401170600.00 ns, 195.8841 us/op
# WorkloadActual  23: 2048 op, 411087100.00 ns, 200.7261 us/op
# WorkloadActual  24: 2048 op, 446732900.00 ns, 218.1313 us/op
# WorkloadActual  25: 2048 op, 392269500.00 ns, 191.5378 us/op
# WorkloadActual  26: 2048 op, 516333900.00 ns, 252.1162 us/op
# WorkloadActual  27: 2048 op, 589912100.00 ns, 288.0430 us/op
# WorkloadActual  28: 2048 op, 493959900.00 ns, 241.1914 us/op
# WorkloadActual  29: 2048 op, 426834400.00 ns, 208.4152 us/op
# WorkloadActual  30: 2048 op, 456025000.00 ns, 222.6685 us/op
# WorkloadActual  31: 2048 op, 633637600.00 ns, 309.3934 us/op
# WorkloadActual  32: 2048 op, 510669100.00 ns, 249.3501 us/op
# WorkloadActual  33: 2048 op, 496149500.00 ns, 242.2605 us/op
# WorkloadActual  34: 2048 op, 508314400.00 ns, 248.2004 us/op
# WorkloadActual  35: 2048 op, 473607600.00 ns, 231.2537 us/op
# WorkloadActual  36: 2048 op, 476986000.00 ns, 232.9033 us/op
# WorkloadActual  37: 2048 op, 430584500.00 ns, 210.2463 us/op
# WorkloadActual  38: 2048 op, 445477700.00 ns, 217.5184 us/op
# WorkloadActual  39: 2048 op, 473427500.00 ns, 231.1658 us/op
# WorkloadActual  40: 2048 op, 1015027700.00 ns, 495.6190 us/op
# WorkloadActual  41: 2048 op, 486035800.00 ns, 237.3222 us/op
# WorkloadActual  42: 2048 op, 470258900.00 ns, 229.6186 us/op
# WorkloadActual  43: 2048 op, 420852200.00 ns, 205.4942 us/op
# WorkloadActual  44: 2048 op, 429889900.00 ns, 209.9072 us/op
# WorkloadActual  45: 2048 op, 415518300.00 ns, 202.8898 us/op
# WorkloadActual  46: 2048 op, 414160300.00 ns, 202.2267 us/op
# WorkloadActual  47: 2048 op, 397239800.00 ns, 193.9647 us/op
# WorkloadActual  48: 2048 op, 378480400.00 ns, 184.8049 us/op
# WorkloadActual  49: 2048 op, 378377300.00 ns, 184.7545 us/op
# WorkloadActual  50: 2048 op, 399527300.00 ns, 195.0817 us/op
# WorkloadActual  51: 2048 op, 523880600.00 ns, 255.8011 us/op
# WorkloadActual  52: 2048 op, 521433400.00 ns, 254.6062 us/op
# WorkloadActual  53: 2048 op, 451720900.00 ns, 220.5668 us/op
# WorkloadActual  54: 2048 op, 1195714700.00 ns, 583.8451 us/op
# WorkloadActual  55: 2048 op, 991548000.00 ns, 484.1543 us/op
# WorkloadActual  56: 2048 op, 1171644000.00 ns, 572.0918 us/op
# WorkloadActual  57: 2048 op, 448341300.00 ns, 218.9167 us/op
# WorkloadActual  58: 2048 op, 473043400.00 ns, 230.9782 us/op
# WorkloadActual  59: 2048 op, 377329500.00 ns, 184.2429 us/op
# WorkloadActual  60: 2048 op, 481036300.00 ns, 234.8810 us/op
# WorkloadActual  61: 2048 op, 498068000.00 ns, 243.1973 us/op
# WorkloadActual  62: 2048 op, 442929500.00 ns, 216.2742 us/op
# WorkloadActual  63: 2048 op, 414136600.00 ns, 202.2151 us/op
# WorkloadActual  64: 2048 op, 444747200.00 ns, 217.1617 us/op
# WorkloadActual  65: 2048 op, 467391100.00 ns, 228.2183 us/op
# WorkloadActual  66: 2048 op, 453877600.00 ns, 221.6199 us/op
# WorkloadActual  67: 2048 op, 387329300.00 ns, 189.1256 us/op
# WorkloadActual  68: 2048 op, 393661300.00 ns, 192.2174 us/op
# WorkloadActual  69: 2048 op, 388580600.00 ns, 189.7366 us/op
# WorkloadActual  70: 2048 op, 396305500.00 ns, 193.5085 us/op
# WorkloadActual  71: 2048 op, 394857000.00 ns, 192.8013 us/op
# WorkloadActual  72: 2048 op, 399497200.00 ns, 195.0670 us/op
# WorkloadActual  73: 2048 op, 452409100.00 ns, 220.9029 us/op
# WorkloadActual  74: 2048 op, 392553400.00 ns, 191.6765 us/op
# WorkloadActual  75: 2048 op, 457385500.00 ns, 223.3328 us/op
# WorkloadActual  76: 2048 op, 546896800.00 ns, 267.0395 us/op
# WorkloadActual  77: 2048 op, 442296700.00 ns, 215.9652 us/op
# WorkloadActual  78: 2048 op, 431555900.00 ns, 210.7207 us/op
# WorkloadActual  79: 2048 op, 440627100.00 ns, 215.1500 us/op
# WorkloadActual  80: 2048 op, 468855100.00 ns, 228.9332 us/op
# WorkloadActual  81: 2048 op, 483518200.00 ns, 236.0929 us/op
# WorkloadActual  82: 2048 op, 1255811600.00 ns, 613.1893 us/op
# WorkloadActual  83: 2048 op, 482929400.00 ns, 235.8054 us/op
# WorkloadActual  84: 2048 op, 590872200.00 ns, 288.5118 us/op
# WorkloadActual  85: 2048 op, 459192100.00 ns, 224.2149 us/op
# WorkloadActual  86: 2048 op, 402529700.00 ns, 196.5477 us/op
# WorkloadActual  87: 2048 op, 386060000.00 ns, 188.5059 us/op
# WorkloadActual  88: 2048 op, 389443300.00 ns, 190.1579 us/op
# WorkloadActual  89: 2048 op, 391063900.00 ns, 190.9492 us/op
# WorkloadActual  90: 2048 op, 391956500.00 ns, 191.3850 us/op
# WorkloadActual  91: 2048 op, 411103100.00 ns, 200.7339 us/op
# WorkloadActual  92: 2048 op, 383833500.00 ns, 187.4187 us/op
# WorkloadActual  93: 2048 op, 409937100.00 ns, 200.1646 us/op
# WorkloadActual  94: 2048 op, 385048200.00 ns, 188.0118 us/op
# WorkloadActual  95: 2048 op, 388563000.00 ns, 189.7280 us/op
# WorkloadActual  96: 2048 op, 440983000.00 ns, 215.3237 us/op
# WorkloadActual  97: 2048 op, 387315900.00 ns, 189.1191 us/op
# WorkloadActual  98: 2048 op, 371078700.00 ns, 181.1908 us/op
# WorkloadActual  99: 2048 op, 382636200.00 ns, 186.8341 us/op
# WorkloadActual  100: 2048 op, 386335200.00 ns, 188.6402 us/op
#
# WorkloadResult   1: 2048 op, 453551000.00 ns, 221.4604 us/op
# WorkloadResult   2: 2048 op, 515685500.00 ns, 251.7996 us/op
# WorkloadResult   3: 2048 op, 447202400.00 ns, 218.3605 us/op
# WorkloadResult   4: 2048 op, 537473100.00 ns, 262.4380 us/op
# WorkloadResult   5: 2048 op, 536852200.00 ns, 262.1349 us/op
# WorkloadResult   6: 2048 op, 433300200.00 ns, 211.5724 us/op
# WorkloadResult   7: 2048 op, 426571900.00 ns, 208.2871 us/op
# WorkloadResult   8: 2048 op, 517992100.00 ns, 252.9258 us/op
# WorkloadResult   9: 2048 op, 411235900.00 ns, 200.7988 us/op
# WorkloadResult  10: 2048 op, 412233700.00 ns, 201.2860 us/op
# WorkloadResult  11: 2048 op, 425642500.00 ns, 207.8333 us/op
# WorkloadResult  12: 2048 op, 447374700.00 ns, 218.4447 us/op
# WorkloadResult  13: 2048 op, 414608600.00 ns, 202.4456 us/op
# WorkloadResult  14: 2048 op, 455867500.00 ns, 222.5916 us/op
# WorkloadResult  15: 2048 op, 437279600.00 ns, 213.5154 us/op
# WorkloadResult  16: 2048 op, 426623400.00 ns, 208.3122 us/op
# WorkloadResult  17: 2048 op, 406712600.00 ns, 198.5901 us/op
# WorkloadResult  18: 2048 op, 410155500.00 ns, 200.2712 us/op
# WorkloadResult  19: 2048 op, 412826700.00 ns, 201.5755 us/op
# WorkloadResult  20: 2048 op, 411572400.00 ns, 200.9631 us/op
# WorkloadResult  21: 2048 op, 404649400.00 ns, 197.5827 us/op
# WorkloadResult  22: 2048 op, 401170600.00 ns, 195.8841 us/op
# WorkloadResult  23: 2048 op, 411087100.00 ns, 200.7261 us/op
# WorkloadResult  24: 2048 op, 446732900.00 ns, 218.1313 us/op
# WorkloadResult  25: 2048 op, 392269500.00 ns, 191.5378 us/op
# WorkloadResult  26: 2048 op, 516333900.00 ns, 252.1162 us/op
# WorkloadResult  27: 2048 op, 589912100.00 ns, 288.0430 us/op
# WorkloadResult  28: 2048 op, 493959900.00 ns, 241.1914 us/op
# WorkloadResult  29: 2048 op, 426834400.00 ns, 208.4152 us/op
# WorkloadResult  30: 2048 op, 456025000.00 ns, 222.6685 us/op
# WorkloadResult  31: 2048 op, 510669100.00 ns, 249.3501 us/op
# WorkloadResult  32: 2048 op, 496149500.00 ns, 242.2605 us/op
# WorkloadResult  33: 2048 op, 508314400.00 ns, 248.2004 us/op
# WorkloadResult  34: 2048 op, 473607600.00 ns, 231.2537 us/op
# WorkloadResult  35: 2048 op, 476986000.00 ns, 232.9033 us/op
# WorkloadResult  36: 2048 op, 430584500.00 ns, 210.2463 us/op
# WorkloadResult  37: 2048 op, 445477700.00 ns, 217.5184 us/op
# WorkloadResult  38: 2048 op, 473427500.00 ns, 231.1658 us/op
# WorkloadResult  39: 2048 op, 486035800.00 ns, 237.3222 us/op
# WorkloadResult  40: 2048 op, 470258900.00 ns, 229.6186 us/op
# WorkloadResult  41: 2048 op, 420852200.00 ns, 205.4942 us/op
# WorkloadResult  42: 2048 op, 429889900.00 ns, 209.9072 us/op
# WorkloadResult  43: 2048 op, 415518300.00 ns, 202.8898 us/op
# WorkloadResult  44: 2048 op, 414160300.00 ns, 202.2267 us/op
# WorkloadResult  45: 2048 op, 397239800.00 ns, 193.9647 us/op
# WorkloadResult  46: 2048 op, 378480400.00 ns, 184.8049 us/op
# WorkloadResult  47: 2048 op, 378377300.00 ns, 184.7545 us/op
# WorkloadResult  48: 2048 op, 399527300.00 ns, 195.0817 us/op
# WorkloadResult  49: 2048 op, 523880600.00 ns, 255.8011 us/op
# WorkloadResult  50: 2048 op, 521433400.00 ns, 254.6062 us/op
# WorkloadResult  51: 2048 op, 451720900.00 ns, 220.5668 us/op
# WorkloadResult  52: 2048 op, 448341300.00 ns, 218.9167 us/op
# WorkloadResult  53: 2048 op, 473043400.00 ns, 230.9782 us/op
# WorkloadResult  54: 2048 op, 377329500.00 ns, 184.2429 us/op
# WorkloadResult  55: 2048 op, 481036300.00 ns, 234.8810 us/op
# WorkloadResult  56: 2048 op, 498068000.00 ns, 243.1973 us/op
# WorkloadResult  57: 2048 op, 442929500.00 ns, 216.2742 us/op
# WorkloadResult  58: 2048 op, 414136600.00 ns, 202.2151 us/op
# WorkloadResult  59: 2048 op, 444747200.00 ns, 217.1617 us/op
# WorkloadResult  60: 2048 op, 467391100.00 ns, 228.2183 us/op
# WorkloadResult  61: 2048 op, 453877600.00 ns, 221.6199 us/op
# WorkloadResult  62: 2048 op, 387329300.00 ns, 189.1256 us/op
# WorkloadResult  63: 2048 op, 393661300.00 ns, 192.2174 us/op
# WorkloadResult  64: 2048 op, 388580600.00 ns, 189.7366 us/op
# WorkloadResult  65: 2048 op, 396305500.00 ns, 193.5085 us/op
# WorkloadResult  66: 2048 op, 394857000.00 ns, 192.8013 us/op
# WorkloadResult  67: 2048 op, 399497200.00 ns, 195.0670 us/op
# WorkloadResult  68: 2048 op, 452409100.00 ns, 220.9029 us/op
# WorkloadResult  69: 2048 op, 392553400.00 ns, 191.6765 us/op
# WorkloadResult  70: 2048 op, 457385500.00 ns, 223.3328 us/op
# WorkloadResult  71: 2048 op, 546896800.00 ns, 267.0395 us/op
# WorkloadResult  72: 2048 op, 442296700.00 ns, 215.9652 us/op
# WorkloadResult  73: 2048 op, 431555900.00 ns, 210.7207 us/op
# WorkloadResult  74: 2048 op, 440627100.00 ns, 215.1500 us/op
# WorkloadResult  75: 2048 op, 468855100.00 ns, 228.9332 us/op
# WorkloadResult  76: 2048 op, 483518200.00 ns, 236.0929 us/op
# WorkloadResult  77: 2048 op, 482929400.00 ns, 235.8054 us/op
# WorkloadResult  78: 2048 op, 590872200.00 ns, 288.5118 us/op
# WorkloadResult  79: 2048 op, 459192100.00 ns, 224.2149 us/op
# WorkloadResult  80: 2048 op, 402529700.00 ns, 196.5477 us/op
# WorkloadResult  81: 2048 op, 386060000.00 ns, 188.5059 us/op
# WorkloadResult  82: 2048 op, 389443300.00 ns, 190.1579 us/op
# WorkloadResult  83: 2048 op, 391063900.00 ns, 190.9492 us/op
# WorkloadResult  84: 2048 op, 391956500.00 ns, 191.3850 us/op
# WorkloadResult  85: 2048 op, 411103100.00 ns, 200.7339 us/op
# WorkloadResult  86: 2048 op, 383833500.00 ns, 187.4187 us/op
# WorkloadResult  87: 2048 op, 409937100.00 ns, 200.1646 us/op
# WorkloadResult  88: 2048 op, 385048200.00 ns, 188.0118 us/op
# WorkloadResult  89: 2048 op, 388563000.00 ns, 189.7280 us/op
# WorkloadResult  90: 2048 op, 440983000.00 ns, 215.3237 us/op
# WorkloadResult  91: 2048 op, 387315900.00 ns, 189.1191 us/op
# WorkloadResult  92: 2048 op, 371078700.00 ns, 181.1908 us/op
# WorkloadResult  93: 2048 op, 382636200.00 ns, 186.8341 us/op
# WorkloadResult  94: 2048 op, 386335200.00 ns, 188.6402 us/op
#
#
# Mean = 215.054 us, StdErr = 2.472 us (1.15%), N = 94, StdDev = 23.965 us
# Min = 181.191 us, Q1 = 195.282 us, Median = 210.483 us, Q3 = 229.447 us, Max = 288.512 us
# IQR = 34.165 us, LowerFence = 144.035 us, UpperFence = 280.695 us
# ConfidenceInterval = [206.654 us; 223.454 us] (CI 99.9%), Margin = 8.400 us (3.91% of Mean)
# Skewness = 0.89, Kurtosis = 3.33, MValue = 2.74
#
# // ** Remained 1 (50.0%) benchmark(s) to run. Estimated finish 2024-02-09 19:16 (0h 7m from now) **
# ]9;4;1;50\Setup power plan (GUID: 8c5e7fda-e8bf-4a96-9a85-a6e23a8c635c FriendlyName: High performance)
# // **************************
# // Benchmark: DapperBenchmarks.StoredProcedure: Job-BQHOSZ(Toolchain=InProcessEmitToolchain)
# // *** Execute ***
# // Launch: 1 / 1
#
# // Benchmark Process Environment Information:
# // BenchmarkDotNet v0.13.12
# // Runtime=.NET 8.0.1 (8.0.123.58001), X64 RyuJIT AVX-512F+CD+BW+DQ+VL+VBMI
# // GC=Concurrent Server
# // HardwareIntrinsics=AVX-512F+CD+BW+DQ+VL+VBMI,AES,BMI1,BMI2,FMA,LZCNT,PCLMUL,POPCNT VectorSize=256
# // Job: Job-BQHOSZ(Toolchain=InProcessEmitToolchain)
#
# OverheadJitting  1: 1 op, 355200.00 ns, 355.2000 us/op
# WorkloadJitting  1: 1 op, 3533025800.00 ns, 3.5330 s/op
#
# OverheadJitting  2: 1 op, 4300.00 ns, 4.3000 us/op
# WorkloadJitting  2: 1 op, 8003200.00 ns, 8.0032 ms/op
#
# OverheadJitting  3: 16 op, 966900.00 ns, 60.4312 us/op
# WorkloadJitting  3: 16 op, 98134200.00 ns, 6.1334 ms/op
#
# WorkloadPilot    1: 16 op, 4965399000.00 ns, 310.3374 ms/op
#
# OverheadWarmup   1: 16 op, 8600.00 ns, 537.5000 ns/op
# OverheadWarmup   2: 16 op, 2100.00 ns, 131.2500 ns/op
# OverheadWarmup   3: 16 op, 2100.00 ns, 131.2500 ns/op
# OverheadWarmup   4: 16 op, 2100.00 ns, 131.2500 ns/op
# OverheadWarmup   5: 16 op, 2800.00 ns, 175.0000 ns/op
# OverheadWarmup   6: 16 op, 2300.00 ns, 143.7500 ns/op
#
# OverheadActual   1: 16 op, 3500.00 ns, 218.7500 ns/op
# OverheadActual   2: 16 op, 2600.00 ns, 162.5000 ns/op
# OverheadActual   3: 16 op, 3000.00 ns, 187.5000 ns/op
# OverheadActual   4: 16 op, 2400.00 ns, 150.0000 ns/op
# OverheadActual   5: 16 op, 2200.00 ns, 137.5000 ns/op
# OverheadActual   6: 16 op, 2600.00 ns, 162.5000 ns/op
# OverheadActual   7: 16 op, 2300.00 ns, 143.7500 ns/op
# OverheadActual   8: 16 op, 2300.00 ns, 143.7500 ns/op
# OverheadActual   9: 16 op, 2100.00 ns, 131.2500 ns/op
# OverheadActual  10: 16 op, 9600.00 ns, 600.0000 ns/op
# OverheadActual  11: 16 op, 2000.00 ns, 125.0000 ns/op
# OverheadActual  12: 16 op, 1700.00 ns, 106.2500 ns/op
# OverheadActual  13: 16 op, 3100.00 ns, 193.7500 ns/op
# OverheadActual  14: 16 op, 2000.00 ns, 125.0000 ns/op
# OverheadActual  15: 16 op, 2800.00 ns, 175.0000 ns/op
# OverheadActual  16: 16 op, 3500.00 ns, 218.7500 ns/op
# OverheadActual  17: 16 op, 8400.00 ns, 525.0000 ns/op
# OverheadActual  18: 16 op, 4500.00 ns, 281.2500 ns/op
# OverheadActual  19: 16 op, 10800.00 ns, 675.0000 ns/op
# OverheadActual  20: 16 op, 3700.00 ns, 231.2500 ns/op
#
# WorkloadWarmup   1: 16 op, 53176100.00 ns, 3.3235 ms/op
# WorkloadWarmup   2: 16 op, 8966483100.00 ns, 560.4052 ms/op
# WorkloadWarmup   3: 16 op, 43156200.00 ns, 2.6973 ms/op
# WorkloadWarmup   4: 16 op, 12421434600.00 ns, 776.3397 ms/op
# WorkloadWarmup   5: 16 op, 49181400.00 ns, 3.0738 ms/op
# WorkloadWarmup   6: 16 op, 890919100.00 ns, 55.6824 ms/op
#
# WorkloadActual   1: 16 op, 2456754800.00 ns, 153.5472 ms/op
# WorkloadActual   2: 16 op, 49663900.00 ns, 3.1040 ms/op
# WorkloadActual   3: 16 op, 2542248900.00 ns, 158.8906 ms/op
# WorkloadActual   4: 16 op, 50753100.00 ns, 3.1721 ms/op
# WorkloadActual   5: 16 op, 63599400.00 ns, 3.9750 ms/op
# WorkloadActual   6: 16 op, 64448300.00 ns, 4.0280 ms/op
# WorkloadActual   7: 16 op, 4096358800.00 ns, 256.0224 ms/op
# WorkloadActual   8: 16 op, 56662500.00 ns, 3.5414 ms/op
# WorkloadActual   9: 16 op, 5175322000.00 ns, 323.4576 ms/op
# WorkloadActual  10: 16 op, 47645800.00 ns, 2.9779 ms/op
# WorkloadActual  11: 16 op, 1370776300.00 ns, 85.6735 ms/op
# WorkloadActual  12: 16 op, 50093300.00 ns, 3.1308 ms/op
# WorkloadActual  13: 16 op, 3000893700.00 ns, 187.5559 ms/op
# WorkloadActual  14: 16 op, 50804800.00 ns, 3.1753 ms/op
# WorkloadActual  15: 16 op, 2207478000.00 ns, 137.9674 ms/op
# WorkloadActual  16: 16 op, 47731600.00 ns, 2.9832 ms/op
# WorkloadActual  17: 16 op, 1768055700.00 ns, 110.5035 ms/op
# WorkloadActual  18: 16 op, 49795000.00 ns, 3.1122 ms/op
# WorkloadActual  19: 16 op, 9239538400.00 ns, 577.4711 ms/op
# WorkloadActual  20: 16 op, 5117064600.00 ns, 319.8165 ms/op
# WorkloadActual  21: 16 op, 61622200.00 ns, 3.8514 ms/op
# WorkloadActual  22: 16 op, 2841697800.00 ns, 177.6061 ms/op
# WorkloadActual  23: 16 op, 49206800.00 ns, 3.0754 ms/op
# WorkloadActual  24: 16 op, 5819311500.00 ns, 363.7070 ms/op
# WorkloadActual  25: 16 op, 47765600.00 ns, 2.9853 ms/op
# WorkloadActual  26: 16 op, 6452588300.00 ns, 403.2868 ms/op
# WorkloadActual  27: 16 op, 41105900.00 ns, 2.5691 ms/op
# WorkloadActual  28: 16 op, 7653460100.00 ns, 478.3413 ms/op
# WorkloadActual  29: 16 op, 46941700.00 ns, 2.9339 ms/op
# WorkloadActual  30: 16 op, 3098372000.00 ns, 193.6482 ms/op
# WorkloadActual  31: 16 op, 55269400.00 ns, 3.4543 ms/op
# WorkloadActual  32: 16 op, 10787656600.00 ns, 674.2285 ms/op
# WorkloadActual  33: 16 op, 14218238600.00 ns, 888.6399 ms/op
# WorkloadActual  34: 16 op, 45865100.00 ns, 2.8666 ms/op
# WorkloadActual  35: 16 op, 6363865200.00 ns, 397.7416 ms/op
# WorkloadActual  36: 16 op, 40434600.00 ns, 2.5272 ms/op
# WorkloadActual  37: 16 op, 5640963300.00 ns, 352.5602 ms/op
# WorkloadActual  38: 16 op, 42272100.00 ns, 2.6420 ms/op
# WorkloadActual  39: 16 op, 2550280300.00 ns, 159.3925 ms/op
# WorkloadActual  40: 16 op, 47496000.00 ns, 2.9685 ms/op
# WorkloadActual  41: 16 op, 2575995300.00 ns, 160.9997 ms/op
# WorkloadActual  42: 16 op, 54450300.00 ns, 3.4031 ms/op
# WorkloadActual  43: 16 op, 3231132100.00 ns, 201.9458 ms/op
# WorkloadActual  44: 16 op, 46765600.00 ns, 2.9228 ms/op
# WorkloadActual  45: 16 op, 5596151300.00 ns, 349.7595 ms/op
# WorkloadActual  46: 16 op, 9326357800.00 ns, 582.8974 ms/op
# WorkloadActual  47: 16 op, 47119300.00 ns, 2.9450 ms/op
# WorkloadActual  48: 16 op, 5808338100.00 ns, 363.0211 ms/op
# WorkloadActual  49: 16 op, 58751200.00 ns, 3.6719 ms/op
# WorkloadActual  50: 16 op, 14268182900.00 ns, 891.7614 ms/op
# WorkloadActual  51: 16 op, 39741100.00 ns, 2.4838 ms/op
# WorkloadActual  52: 16 op, 2953643500.00 ns, 184.6027 ms/op
# WorkloadActual  53: 16 op, 3500002200.00 ns, 218.7501 ms/op
# WorkloadActual  54: 16 op, 47688900.00 ns, 2.9806 ms/op
# WorkloadActual  55: 16 op, 5332308000.00 ns, 333.2692 ms/op
# WorkloadActual  56: 16 op, 47382700.00 ns, 2.9614 ms/op
# WorkloadActual  57: 16 op, 5563458000.00 ns, 347.7161 ms/op
# WorkloadActual  58: 16 op, 37943100.00 ns, 2.3714 ms/op
# WorkloadActual  59: 16 op, 10085739400.00 ns, 630.3587 ms/op
# WorkloadActual  60: 16 op, 36848900.00 ns, 2.3031 ms/op
# WorkloadActual  61: 16 op, 728803000.00 ns, 45.5502 ms/op
# WorkloadActual  62: 16 op, 14726221400.00 ns, 920.3888 ms/op
# WorkloadActual  63: 16 op, 48835500.00 ns, 3.0522 ms/op
# WorkloadActual  64: 16 op, 9838879700.00 ns, 614.9300 ms/op
# WorkloadActual  65: 16 op, 42719400.00 ns, 2.6700 ms/op
# WorkloadActual  66: 16 op, 14982550600.00 ns, 936.4094 ms/op
# WorkloadActual  67: 16 op, 38930800.00 ns, 2.4332 ms/op
# WorkloadActual  68: 16 op, 4066860300.00 ns, 254.1788 ms/op
# WorkloadActual  69: 16 op, 50166800.00 ns, 3.1354 ms/op
# WorkloadActual  70: 16 op, 4641765200.00 ns, 290.1103 ms/op
# WorkloadActual  71: 16 op, 46850700.00 ns, 2.9282 ms/op
# WorkloadActual  72: 16 op, 828326000.00 ns, 51.7704 ms/op
# WorkloadActual  73: 16 op, 56720300.00 ns, 3.5450 ms/op
# WorkloadActual  74: 16 op, 4129128400.00 ns, 258.0705 ms/op
# WorkloadActual  75: 16 op, 51332400.00 ns, 3.2083 ms/op
# WorkloadActual  76: 16 op, 7945388500.00 ns, 496.5868 ms/op
# WorkloadActual  77: 16 op, 42606100.00 ns, 2.6629 ms/op
# WorkloadActual  78: 16 op, 7189393400.00 ns, 449.3371 ms/op
# WorkloadActual  79: 16 op, 37681400.00 ns, 2.3551 ms/op
# WorkloadActual  80: 16 op, 6833322300.00 ns, 427.0826 ms/op
# WorkloadActual  81: 16 op, 39255700.00 ns, 2.4535 ms/op
# WorkloadActual  82: 16 op, 14080798400.00 ns, 880.0499 ms/op
# WorkloadActual  83: 16 op, 40828000.00 ns, 2.5518 ms/op
# WorkloadActual  84: 16 op, 5904245700.00 ns, 369.0154 ms/op
# WorkloadActual  85: 16 op, 48884600.00 ns, 3.0553 ms/op
# WorkloadActual  86: 16 op, 4348648000.00 ns, 271.7905 ms/op
# WorkloadActual  87: 16 op, 50154900.00 ns, 3.1347 ms/op
# WorkloadActual  88: 16 op, 4783246900.00 ns, 298.9529 ms/op
# WorkloadActual  89: 16 op, 53418300.00 ns, 3.3386 ms/op
# WorkloadActual  90: 16 op, 4089810400.00 ns, 255.6131 ms/op
# WorkloadActual  91: 16 op, 39562900.00 ns, 2.4727 ms/op
# WorkloadActual  92: 16 op, 3582107800.00 ns, 223.8817 ms/op
# WorkloadActual  93: 16 op, 12221401300.00 ns, 763.8376 ms/op
# WorkloadActual  94: 16 op, 48470300.00 ns, 3.0294 ms/op
# WorkloadActual  95: 16 op, 5126391900.00 ns, 320.3995 ms/op
# WorkloadActual  96: 16 op, 39436300.00 ns, 2.4648 ms/op
# WorkloadActual  97: 16 op, 16280886100.00 ns, 1.0176 s/op
# WorkloadActual  98: 16 op, 38333100.00 ns, 2.3958 ms/op
# WorkloadActual  99: 16 op, 1519657500.00 ns, 94.9786 ms/op
# WorkloadActual  100: 16 op, 38977100.00 ns, 2.4361 ms/op
#
# WorkloadResult   1: 16 op, 2456752100.00 ns, 153.5470 ms/op
# WorkloadResult   2: 16 op, 49661200.00 ns, 3.1038 ms/op
# WorkloadResult   3: 16 op, 2542246200.00 ns, 158.8904 ms/op
# WorkloadResult   4: 16 op, 50750400.00 ns, 3.1719 ms/op
# WorkloadResult   5: 16 op, 63596700.00 ns, 3.9748 ms/op
# WorkloadResult   6: 16 op, 64445600.00 ns, 4.0278 ms/op
# WorkloadResult   7: 16 op, 4096356100.00 ns, 256.0223 ms/op
# WorkloadResult   8: 16 op, 56659800.00 ns, 3.5412 ms/op
# WorkloadResult   9: 16 op, 5175319300.00 ns, 323.4575 ms/op
# WorkloadResult  10: 16 op, 47643100.00 ns, 2.9777 ms/op
# WorkloadResult  11: 16 op, 1370773600.00 ns, 85.6733 ms/op
# WorkloadResult  12: 16 op, 50090600.00 ns, 3.1307 ms/op
# WorkloadResult  13: 16 op, 3000891000.00 ns, 187.5557 ms/op
# WorkloadResult  14: 16 op, 50802100.00 ns, 3.1751 ms/op
# WorkloadResult  15: 16 op, 2207475300.00 ns, 137.9672 ms/op
# WorkloadResult  16: 16 op, 47728900.00 ns, 2.9831 ms/op
# WorkloadResult  17: 16 op, 1768053000.00 ns, 110.5033 ms/op
# WorkloadResult  18: 16 op, 49792300.00 ns, 3.1120 ms/op
# WorkloadResult  19: 16 op, 9239535700.00 ns, 577.4710 ms/op
# WorkloadResult  20: 16 op, 5117061900.00 ns, 319.8164 ms/op
# WorkloadResult  21: 16 op, 61619500.00 ns, 3.8512 ms/op
# WorkloadResult  22: 16 op, 2841695100.00 ns, 177.6059 ms/op
# WorkloadResult  23: 16 op, 49204100.00 ns, 3.0753 ms/op
# WorkloadResult  24: 16 op, 5819308800.00 ns, 363.7068 ms/op
# WorkloadResult  25: 16 op, 47762900.00 ns, 2.9852 ms/op
# WorkloadResult  26: 16 op, 6452585600.00 ns, 403.2866 ms/op
# WorkloadResult  27: 16 op, 41103200.00 ns, 2.5690 ms/op
# WorkloadResult  28: 16 op, 7653457400.00 ns, 478.3411 ms/op
# WorkloadResult  29: 16 op, 46939000.00 ns, 2.9337 ms/op
# WorkloadResult  30: 16 op, 3098369300.00 ns, 193.6481 ms/op
# WorkloadResult  31: 16 op, 55266700.00 ns, 3.4542 ms/op
# WorkloadResult  32: 16 op, 10787653900.00 ns, 674.2284 ms/op
# WorkloadResult  33: 16 op, 45862400.00 ns, 2.8664 ms/op
# WorkloadResult  34: 16 op, 6363862500.00 ns, 397.7414 ms/op
# WorkloadResult  35: 16 op, 40431900.00 ns, 2.5270 ms/op
# WorkloadResult  36: 16 op, 5640960600.00 ns, 352.5600 ms/op
# WorkloadResult  37: 16 op, 42269400.00 ns, 2.6418 ms/op
# WorkloadResult  38: 16 op, 2550277600.00 ns, 159.3923 ms/op
# WorkloadResult  39: 16 op, 47493300.00 ns, 2.9683 ms/op
# WorkloadResult  40: 16 op, 2575992600.00 ns, 160.9995 ms/op
# WorkloadResult  41: 16 op, 54447600.00 ns, 3.4030 ms/op
# WorkloadResult  42: 16 op, 3231129400.00 ns, 201.9456 ms/op
# WorkloadResult  43: 16 op, 46762900.00 ns, 2.9227 ms/op
# WorkloadResult  44: 16 op, 5596148600.00 ns, 349.7593 ms/op
# WorkloadResult  45: 16 op, 9326355100.00 ns, 582.8972 ms/op
# WorkloadResult  46: 16 op, 47116600.00 ns, 2.9448 ms/op
# WorkloadResult  47: 16 op, 5808335400.00 ns, 363.0210 ms/op
# WorkloadResult  48: 16 op, 58748500.00 ns, 3.6718 ms/op
# WorkloadResult  49: 16 op, 39738400.00 ns, 2.4836 ms/op
# WorkloadResult  50: 16 op, 2953640800.00 ns, 184.6026 ms/op
# WorkloadResult  51: 16 op, 3499999500.00 ns, 218.7500 ms/op
# WorkloadResult  52: 16 op, 47686200.00 ns, 2.9804 ms/op
# WorkloadResult  53: 16 op, 5332305300.00 ns, 333.2691 ms/op
# WorkloadResult  54: 16 op, 47380000.00 ns, 2.9613 ms/op
# WorkloadResult  55: 16 op, 5563455300.00 ns, 347.7160 ms/op
# WorkloadResult  56: 16 op, 37940400.00 ns, 2.3713 ms/op
# WorkloadResult  57: 16 op, 10085736700.00 ns, 630.3585 ms/op
# WorkloadResult  58: 16 op, 36846200.00 ns, 2.3029 ms/op
# WorkloadResult  59: 16 op, 728800300.00 ns, 45.5500 ms/op
# WorkloadResult  60: 16 op, 48832800.00 ns, 3.0520 ms/op
# WorkloadResult  61: 16 op, 9838877000.00 ns, 614.9298 ms/op
# WorkloadResult  62: 16 op, 42716700.00 ns, 2.6698 ms/op
# WorkloadResult  63: 16 op, 38928100.00 ns, 2.4330 ms/op
# WorkloadResult  64: 16 op, 4066857600.00 ns, 254.1786 ms/op
# WorkloadResult  65: 16 op, 50164100.00 ns, 3.1353 ms/op
# WorkloadResult  66: 16 op, 4641762500.00 ns, 290.1102 ms/op
# WorkloadResult  67: 16 op, 46848000.00 ns, 2.9280 ms/op
# WorkloadResult  68: 16 op, 828323300.00 ns, 51.7702 ms/op
# WorkloadResult  69: 16 op, 56717600.00 ns, 3.5448 ms/op
# WorkloadResult  70: 16 op, 4129125700.00 ns, 258.0704 ms/op
# WorkloadResult  71: 16 op, 51329700.00 ns, 3.2081 ms/op
# WorkloadResult  72: 16 op, 7945385800.00 ns, 496.5866 ms/op
# WorkloadResult  73: 16 op, 42603400.00 ns, 2.6627 ms/op
# WorkloadResult  74: 16 op, 7189390700.00 ns, 449.3369 ms/op
# WorkloadResult  75: 16 op, 37678700.00 ns, 2.3549 ms/op
# WorkloadResult  76: 16 op, 6833319600.00 ns, 427.0825 ms/op
# WorkloadResult  77: 16 op, 39253000.00 ns, 2.4533 ms/op
# WorkloadResult  78: 16 op, 40825300.00 ns, 2.5516 ms/op
# WorkloadResult  79: 16 op, 5904243000.00 ns, 369.0152 ms/op
# WorkloadResult  80: 16 op, 48881900.00 ns, 3.0551 ms/op
# WorkloadResult  81: 16 op, 4348645300.00 ns, 271.7903 ms/op
# WorkloadResult  82: 16 op, 50152200.00 ns, 3.1345 ms/op
# WorkloadResult  83: 16 op, 4783244200.00 ns, 298.9528 ms/op
# WorkloadResult  84: 16 op, 53415600.00 ns, 3.3385 ms/op
# WorkloadResult  85: 16 op, 4089807700.00 ns, 255.6130 ms/op
# WorkloadResult  86: 16 op, 39560200.00 ns, 2.4725 ms/op
# WorkloadResult  87: 16 op, 3582105100.00 ns, 223.8816 ms/op
# WorkloadResult  88: 16 op, 12221398600.00 ns, 763.8374 ms/op
# WorkloadResult  89: 16 op, 48467600.00 ns, 3.0292 ms/op
# WorkloadResult  90: 16 op, 5126389200.00 ns, 320.3993 ms/op
# WorkloadResult  91: 16 op, 39433600.00 ns, 2.4646 ms/op
# WorkloadResult  92: 16 op, 38330400.00 ns, 2.3956 ms/op
# WorkloadResult  93: 16 op, 1519654800.00 ns, 94.9784 ms/op
# WorkloadResult  94: 16 op, 38974400.00 ns, 2.4359 ms/op
#
#
# Mean = 154.396 ms, StdErr = 20.164 ms (13.06%), N = 94, StdDev = 195.498 ms
# Min = 2.303 ms, Q1 = 2.978 ms, Median = 4.001 ms, Q3 = 285.530 ms, Max = 763.837 ms
# IQR = 282.552 ms, LowerFence = -420.849 ms, UpperFence = 709.358 ms
# ConfidenceInterval = [85.874 ms; 222.919 ms] (CI 99.9%), Margin = 68.522 ms (44.38% of Mean)
# Skewness = 1.12, Kurtosis = 3.34, MValue = 2.69
#
# // ** Remained 0 (0.0%) benchmark(s) to run. Estimated finish 2024-02-09 19:19 (0h 0m from now) **
# ]9;4;1;100\Successfully reverted power plan (GUID: 381b4222-f694-41f0-9685-ff5bb260df2e FriendlyName: Balanced)
# // ***** BenchmarkRunner: Finish  *****
#
# // * Export *
#
# // * Detailed results *
# DapperBenchmarks.SqlQuery: Job-BQHOSZ(Toolchain=InProcessEmitToolchain)
# Runtime = ; GC =
# Mean = 215.054 us, StdErr = 2.472 us (1.15%), N = 94, StdDev = 23.965 us
# Min = 181.191 us, Q1 = 195.282 us, Median = 210.483 us, Q3 = 229.447 us, Max = 288.512 us
# IQR = 34.165 us, LowerFence = 144.035 us, UpperFence = 280.695 us
# ConfidenceInterval = [206.654 us; 223.454 us] (CI 99.9%), Margin = 8.400 us (3.91% of Mean)
# Skewness = 0.89, Kurtosis = 3.33, MValue = 2.74
# -------------------- Histogram --------------------
# [174.273 us ; 188.448 us) | @@@@@@@
# [188.448 us ; 202.284 us) | @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# [202.284 us ; 207.809 us) | @@@
# [207.809 us ; 221.645 us) | @@@@@@@@@@@@@@@@@@@@@@@
# [221.645 us ; 236.260 us) | @@@@@@@@@@@@@@
# [236.260 us ; 254.817 us) | @@@@@@@@@@
# [254.817 us ; 268.338 us) | @@@@
# [268.338 us ; 281.359 us) |
# [281.359 us ; 295.430 us) | @@
# ---------------------------------------------------
#
# DapperBenchmarks.StoredProcedure: Job-BQHOSZ(Toolchain=InProcessEmitToolchain)
# Runtime = ; GC =
# Mean = 154.396 ms, StdErr = 20.164 ms (13.06%), N = 94, StdDev = 195.498 ms
# Min = 2.303 ms, Q1 = 2.978 ms, Median = 4.001 ms, Q3 = 285.530 ms, Max = 763.837 ms
# IQR = 282.552 ms, LowerFence = -420.849 ms, UpperFence = 709.358 ms
# ConfidenceInterval = [85.874 ms; 222.919 ms] (CI 99.9%), Margin = 68.522 ms (44.38% of Mean)
# Skewness = 1.12, Kurtosis = 3.34, MValue = 2.69
# -------------------- Histogram --------------------
# [ -0.030 ms ; 124.491 ms) | @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# [124.491 ms ; 252.510 ms) | @@@@@@@@@@@@
# [252.510 ms ; 390.731 ms) | @@@@@@@@@@@@@@@@@
# [390.731 ms ; 503.597 ms) | @@@@@@
# [503.597 ms ; 569.417 ms) |
# [569.417 ms ; 682.283 ms) | @@@@@
# [682.283 ms ; 820.270 ms) | @
# ---------------------------------------------------
#
# // * Summary *
#
# BenchmarkDotNet v0.13.12, Windows 11 (10.0.22631.3085/23H2/2023Update/SunValley3)
# 11th Gen Intel Core i7-11800H 2.30GHz, 1 CPU, 16 logical and 8 physical cores
# .NET SDK 8.0.101
#   [Host] : .NET 8.0.1 (8.0.123.58001), X64 RyuJIT AVX-512F+CD+BW+DQ+VL+VBMI
#
# Toolchain=InProcessEmitToolchain
#
# | Method          | Mean         | Error        | StdDev        | Median     |
# |---------------- |-------------:|-------------:|--------------:|-----------:|
# | SqlQuery        |     215.1 us |      8.40 us |      23.97 us |   210.5 us |
# | StoredProcedure | 154,396.3 us | 68,522.46 us | 195,498.44 us | 4,001.3 us |
#
# // * Legends *
#   Mean   : Arithmetic mean of all measurements
#   Error  : Half of 99.9% confidence interval
#   StdDev : Standard deviation of all measurements
#   Median : Value separating the higher half of all measurements (50th percentile)
#   1 us   : 1 Microsecond (0.000001 sec)
#
# // ***** BenchmarkRunner: End *****
# Run time: 00:17:48 (1068.91 sec), executed benchmarks: 2
#
# Global total time: 00:17:49 (1069.37 sec), executed benchmarks: 2
# // * Artifacts cleanup *
# Artifacts cleanup is finished
# ]9;4;0;0\BenchmarkDotNet.Reports.Summary

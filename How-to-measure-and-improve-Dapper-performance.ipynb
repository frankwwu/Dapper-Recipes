# %% [markdown]
# # How to measure and improve Dapper performance
#
# To measure and improve Dapper performance with C#, you can use the following steps:
#
# - Install the Dapper and BenchmarkDotNet in your project.
# - Create a class that implements the <code>IBenchmark</code> interface and defines the methods for setting up, executing, and cleaning up the benchmark.
# - Create a connection to the AdventureWorks2022 database using the <code>SqlConnection</code> class and the connection string.
# - In the execute method, use the <code>Query</code> extension method of Dapper to execute a SQL query and map the results to a C# object. For example, you can query the Product table and map the results to a Product class.
# - In the cleanup method, dispose the connection object and release any resources used by the benchmark.
# - Use the <code>BenchmarkRunner</code> class to run the benchmark and generate a report that shows the performance metrics such as mean time, standard deviation, allocations, etc.
# - To improve the performance of Dapper, you can try some of the following tips:
#     * Use parameterized queries instead of string concatenation or interpolation to avoid SQL injection and improve query plan caching.
#     * Use the <code>Buffered</code> parameter of the <code>Query</code> method to control whether the results are buffered in memory or streamed from the database. Buffering can improve performance for small result sets, but streaming can reduce memory usage for large result sets.
#     * Use the <code>SplitOn</code> parameter of the <code>Query</code> method to specify the column name that separates the objects in a multi-mapping query. This can avoid unnecessary reflection and improve mapping speed.
#     * Use the <code>AsNoTracking</code> extension method of EF Core to disable change tracking and improve query performance when you only need to read data from the database.

# %% [markdown]
# Here is a C# example of how to use <code>BenchmarkRunner</code> with Dapper. It assumes that you have installed the Dapper and BenchmarkDotNet NuGet packages, and that you have a connection string to the AdventureWorks2022 database. The example benchmarks two methods that query the Product table using different approaches: one using raw SQL and the other using stored procedure. The results are printed to the console and exported to a markdown file.

# %%
// Connection string
#load "AppSettings.cs"

# %%
#r "nuget:Dapper"
#r "nuget:BenchmarkDotNet"
#r "nuget:Microsoft.Data.SqlClient"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>BenchmarkDotNet, 0.13.12</span></li><li><span>Dapper, 2.1.28</span></li><li><span>Microsoft.Data.SqlClient, 5.1.5</span></li></ul></div></div>

# %%
using System;
using System.Data;
using Microsoft.Data.SqlClient;
using BenchmarkDotNet.Attributes;
using BenchmarkDotNet.Running;
using BenchmarkDotNet.Configs;
using Dapper;

public class Product
{
    public int ProductID { get; set; }
    public string Name { get; set; }
    public decimal ListPrice { get; set; }
}

public class Employee
{
    public int BusinessEntityID { get; set; }
    public int RecursionLevel { get; set; }   
    public string FirstName { get; set; }
    public string LastName { get; set; }
    public string ManagerFirstName { get; set; }
    public string ManagerLastName { get; set; }
}

public class DapperBenchmarks
{   
    private const string sqlQuery = "SELECT ProductID, Name, ListPrice FROM Production.Product WHERE ListPrice > 3000";
    private const string storedProcedure = "uspGetEmployeeManagers";

    [Benchmark]
    public Product[] SqlQuery()
    {
        using (var connection = new SqlConnection(connectionString))
        {
            return connection.Query<Product>(sqlQuery).ToArray();
        }
    }

    [Benchmark]
    public Employee[] StoredProcedure()
    {
        using (var connection = new SqlConnection(connectionString))
        {
            DynamicParameters parameters = new DynamicParameters();
            parameters.Add("@BusinessEntityID", 12);           
            return connection.Query<Employee>(storedProcedure, parameters, commandType: CommandType.StoredProcedure).ToArray();
        }
    }
}

# %%
var summary = BenchmarkRunner.Run<DapperBenchmarks>(new DebugInProcessConfig());
Console.WriteLine(summary);
# Out:
# ]9;4;3;0\// Validating benchmarks:
# //    * No exporters defined, results will not be persisted.
#
# // ***** BenchmarkRunner: Start   *****
# // ***** Found 2 benchmark(s) in total *****
# // ***** Building 1 exe(s) in Parallel: Start   *****
# // ***** Done, took 00:00:00 (0.03 sec)   *****
# // Found 2 benchmarks:
# //   DapperBenchmarks.SqlQuery: Job-SVIBJL(Toolchain=InProcessEmitToolchain)
# //   DapperBenchmarks.StoredProcedure: Job-SVIBJL(Toolchain=InProcessEmitToolchain)
#
# Setup power plan (GUID: 8c5e7fda-e8bf-4a96-9a85-a6e23a8c635c FriendlyName: High performance)
# // **************************
# // Benchmark: DapperBenchmarks.SqlQuery: Job-SVIBJL(Toolchain=InProcessEmitToolchain)
# // *** Execute ***
# // Launch: 1 / 1
#
# // Benchmark Process Environment Information:
# // BenchmarkDotNet v0.13.12
# // Runtime=.NET 8.0.1 (8.0.123.58001), X64 RyuJIT AVX-512F+CD+BW+DQ+VL+VBMI
# // GC=Concurrent Server
# // HardwareIntrinsics=AVX-512F+CD+BW+DQ+VL+VBMI,AES,BMI1,BMI2,FMA,LZCNT,PCLMUL,POPCNT VectorSize=256
# // Job: Job-SVIBJL(Toolchain=InProcessEmitToolchain)
#
# OverheadJitting  1: 1 op, 355600.00 ns, 355.6000 us/op
# WorkloadJitting  1: 1 op, 200831300.00 ns, 200.8313 ms/op
#
# WorkloadPilot    1: 2 op, 4322300.00 ns, 2.1612 ms/op
# WorkloadPilot    2: 3 op, 2023300.00 ns, 674.4333 us/op
# WorkloadPilot    3: 4 op, 3858900.00 ns, 964.7250 us/op
# WorkloadPilot    4: 5 op, 2734800.00 ns, 546.9600 us/op
# WorkloadPilot    5: 6 op, 5227600.00 ns, 871.2667 us/op
# WorkloadPilot    6: 7 op, 4881300.00 ns, 697.3286 us/op
# WorkloadPilot    7: 8 op, 5635400.00 ns, 704.4250 us/op
# WorkloadPilot    8: 9 op, 6746500.00 ns, 749.6111 us/op
# WorkloadPilot    9: 10 op, 6414800.00 ns, 641.4800 us/op
# WorkloadPilot   10: 11 op, 5895500.00 ns, 535.9545 us/op
# WorkloadPilot   11: 12 op, 5914900.00 ns, 492.9083 us/op
# WorkloadPilot   12: 13 op, 5973400.00 ns, 459.4923 us/op
# WorkloadPilot   13: 14 op, 6909400.00 ns, 493.5286 us/op
# WorkloadPilot   14: 15 op, 4373900.00 ns, 291.5933 us/op
# WorkloadPilot   15: 16 op, 5469900.00 ns, 341.8687 us/op
# WorkloadPilot   16: 32 op, 9292500.00 ns, 290.3906 us/op
# WorkloadPilot   17: 64 op, 17958600.00 ns, 280.6031 us/op
# WorkloadPilot   18: 128 op, 36922800.00 ns, 288.4594 us/op
# WorkloadPilot   19: 256 op, 71902900.00 ns, 280.8707 us/op
# WorkloadPilot   20: 512 op, 130525300.00 ns, 254.9322 us/op
# WorkloadPilot   21: 1024 op, 277787300.00 ns, 271.2767 us/op
# WorkloadPilot   22: 2048 op, 537161600.00 ns, 262.2859 us/op
#
# WorkloadWarmup   1: 2048 op, 554140600.00 ns, 270.5765 us/op
# WorkloadWarmup   2: 2048 op, 521211100.00 ns, 254.4976 us/op
# WorkloadWarmup   3: 2048 op, 440325700.00 ns, 215.0028 us/op
# WorkloadWarmup   4: 2048 op, 448877600.00 ns, 219.1785 us/op
# WorkloadWarmup   5: 2048 op, 427292400.00 ns, 208.6389 us/op
# WorkloadWarmup   6: 2048 op, 419471500.00 ns, 204.8201 us/op
# WorkloadWarmup   7: 2048 op, 446593200.00 ns, 218.0631 us/op
# WorkloadWarmup   8: 2048 op, 421857100.00 ns, 205.9849 us/op
#
# WorkloadActual   1: 2048 op, 406132500.00 ns, 198.3069 us/op
# WorkloadActual   2: 2048 op, 468579900.00 ns, 228.7988 us/op
# WorkloadActual   3: 2048 op, 465949300.00 ns, 227.5143 us/op
# WorkloadActual   4: 2048 op, 431471400.00 ns, 210.6794 us/op
# WorkloadActual   5: 2048 op, 528337000.00 ns, 257.9771 us/op
# WorkloadActual   6: 2048 op, 462244900.00 ns, 225.7055 us/op
# WorkloadActual   7: 2048 op, 409819600.00 ns, 200.1072 us/op
# WorkloadActual   8: 2048 op, 426075900.00 ns, 208.0449 us/op
# WorkloadActual   9: 2048 op, 558515700.00 ns, 272.7127 us/op
# WorkloadActual  10: 2048 op, 463856400.00 ns, 226.4924 us/op
# WorkloadActual  11: 2048 op, 519500700.00 ns, 253.6625 us/op
# WorkloadActual  12: 2048 op, 527820800.00 ns, 257.7250 us/op
# WorkloadActual  13: 2048 op, 545278300.00 ns, 266.2492 us/op
# WorkloadActual  14: 2048 op, 451437600.00 ns, 220.4285 us/op
# WorkloadActual  15: 2048 op, 423155400.00 ns, 206.6188 us/op
# WorkloadActual  16: 2048 op, 412305300.00 ns, 201.3209 us/op
# WorkloadActual  17: 2048 op, 414342500.00 ns, 202.3157 us/op
# WorkloadActual  18: 2048 op, 419886700.00 ns, 205.0228 us/op
# WorkloadActual  19: 2048 op, 414905900.00 ns, 202.5908 us/op
# WorkloadActual  20: 2048 op, 418287400.00 ns, 204.2419 us/op
# WorkloadActual  21: 2048 op, 394263600.00 ns, 192.5115 us/op
# WorkloadActual  22: 2048 op, 411904700.00 ns, 201.1253 us/op
# WorkloadActual  23: 2048 op, 410202000.00 ns, 200.2939 us/op
# WorkloadActual  24: 2048 op, 404524300.00 ns, 197.5216 us/op
# WorkloadActual  25: 2048 op, 430843800.00 ns, 210.3729 us/op
# WorkloadActual  26: 2048 op, 439129000.00 ns, 214.4185 us/op
# WorkloadActual  27: 2048 op, 402873500.00 ns, 196.7156 us/op
# WorkloadActual  28: 2048 op, 407088300.00 ns, 198.7736 us/op
# WorkloadActual  29: 2048 op, 411798500.00 ns, 201.0735 us/op
# WorkloadActual  30: 2048 op, 411751900.00 ns, 201.0507 us/op
# WorkloadActual  31: 2048 op, 405787200.00 ns, 198.1383 us/op
# WorkloadActual  32: 2048 op, 408633300.00 ns, 199.5280 us/op
# WorkloadActual  33: 2048 op, 402352900.00 ns, 196.4614 us/op
# WorkloadActual  34: 2048 op, 409113700.00 ns, 199.7625 us/op
# WorkloadActual  35: 2048 op, 404377200.00 ns, 197.4498 us/op
# WorkloadActual  36: 2048 op, 393372700.00 ns, 192.0765 us/op
# WorkloadActual  37: 2048 op, 405554200.00 ns, 198.0245 us/op
# WorkloadActual  38: 2048 op, 411718800.00 ns, 201.0346 us/op
# WorkloadActual  39: 2048 op, 410543100.00 ns, 200.4605 us/op
# WorkloadActual  40: 2048 op, 409394600.00 ns, 199.8997 us/op
# WorkloadActual  41: 2048 op, 427482900.00 ns, 208.7319 us/op
# WorkloadActual  42: 2048 op, 415335800.00 ns, 202.8007 us/op
# WorkloadActual  43: 2048 op, 413380500.00 ns, 201.8459 us/op
# WorkloadActual  44: 2048 op, 423759200.00 ns, 206.9137 us/op
# WorkloadActual  45: 2048 op, 417391500.00 ns, 203.8044 us/op
# WorkloadActual  46: 2048 op, 420166100.00 ns, 205.1592 us/op
# WorkloadActual  47: 2048 op, 442297900.00 ns, 215.9658 us/op
# WorkloadActual  48: 2048 op, 446883100.00 ns, 218.2046 us/op
# WorkloadActual  49: 2048 op, 447973200.00 ns, 218.7369 us/op
# WorkloadActual  50: 2048 op, 550344300.00 ns, 268.7228 us/op
# WorkloadActual  51: 2048 op, 474761800.00 ns, 231.8173 us/op
# WorkloadActual  52: 2048 op, 456270000.00 ns, 222.7881 us/op
# WorkloadActual  53: 2048 op, 457199300.00 ns, 223.2418 us/op
# WorkloadActual  54: 2048 op, 465187400.00 ns, 227.1423 us/op
# WorkloadActual  55: 2048 op, 463401700.00 ns, 226.2704 us/op
# WorkloadActual  56: 2048 op, 508817400.00 ns, 248.4460 us/op
# WorkloadActual  57: 2048 op, 487639200.00 ns, 238.1051 us/op
# WorkloadActual  58: 2048 op, 486899900.00 ns, 237.7441 us/op
# WorkloadActual  59: 2048 op, 560979300.00 ns, 273.9157 us/op
# WorkloadActual  60: 2048 op, 520388000.00 ns, 254.0957 us/op
# WorkloadActual  61: 2048 op, 452534600.00 ns, 220.9642 us/op
# WorkloadActual  62: 2048 op, 453119100.00 ns, 221.2496 us/op
# WorkloadActual  63: 2048 op, 469205300.00 ns, 229.1042 us/op
# WorkloadActual  64: 2048 op, 448281200.00 ns, 218.8873 us/op
# WorkloadActual  65: 2048 op, 454644800.00 ns, 221.9945 us/op
# WorkloadActual  66: 2048 op, 462175100.00 ns, 225.6714 us/op
# WorkloadActual  67: 2048 op, 585479900.00 ns, 285.8789 us/op
# WorkloadActual  68: 2048 op, 509888700.00 ns, 248.9691 us/op
# WorkloadActual  69: 2048 op, 599173600.00 ns, 292.5652 us/op
# WorkloadActual  70: 2048 op, 578803700.00 ns, 282.6190 us/op
# WorkloadActual  71: 2048 op, 519188700.00 ns, 253.5101 us/op
# WorkloadActual  72: 2048 op, 518143400.00 ns, 252.9997 us/op
# WorkloadActual  73: 2048 op, 504791700.00 ns, 246.4803 us/op
# WorkloadActual  74: 2048 op, 467173600.00 ns, 228.1121 us/op
# WorkloadActual  75: 2048 op, 425655600.00 ns, 207.8396 us/op
# WorkloadActual  76: 2048 op, 483172100.00 ns, 235.9239 us/op
# WorkloadActual  77: 2048 op, 455043700.00 ns, 222.1893 us/op
# WorkloadActual  78: 2048 op, 456447000.00 ns, 222.8745 us/op
# WorkloadActual  79: 2048 op, 441240600.00 ns, 215.4495 us/op
# WorkloadActual  80: 2048 op, 547374700.00 ns, 267.2728 us/op
# WorkloadActual  81: 2048 op, 496511400.00 ns, 242.4372 us/op
# WorkloadActual  82: 2048 op, 625944400.00 ns, 305.6369 us/op
# WorkloadActual  83: 2048 op, 690493100.00 ns, 337.1548 us/op
# WorkloadActual  84: 2048 op, 576744400.00 ns, 281.6135 us/op
# WorkloadActual  85: 2048 op, 597037100.00 ns, 291.5220 us/op
# WorkloadActual  86: 2048 op, 528681200.00 ns, 258.1451 us/op
# WorkloadActual  87: 2048 op, 546375300.00 ns, 266.7848 us/op
# WorkloadActual  88: 2048 op, 525887200.00 ns, 256.7809 us/op
# WorkloadActual  89: 2048 op, 530096900.00 ns, 258.8364 us/op
# WorkloadActual  90: 2048 op, 524984700.00 ns, 256.3402 us/op
# WorkloadActual  91: 2048 op, 459947900.00 ns, 224.5839 us/op
# WorkloadActual  92: 2048 op, 442605400.00 ns, 216.1159 us/op
# WorkloadActual  93: 2048 op, 481327500.00 ns, 235.0232 us/op
# WorkloadActual  94: 2048 op, 488318100.00 ns, 238.4366 us/op
# WorkloadActual  95: 2048 op, 589137500.00 ns, 287.6648 us/op
# WorkloadActual  96: 2048 op, 610769300.00 ns, 298.2272 us/op
# WorkloadActual  97: 2048 op, 581887500.00 ns, 284.1248 us/op
# WorkloadActual  98: 2048 op, 497602100.00 ns, 242.9698 us/op
# WorkloadActual  99: 2048 op, 504717100.00 ns, 246.4439 us/op
# WorkloadActual  100: 2048 op, 494349900.00 ns, 241.3818 us/op
#
# WorkloadResult   1: 2048 op, 406132500.00 ns, 198.3069 us/op
# WorkloadResult   2: 2048 op, 468579900.00 ns, 228.7988 us/op
# WorkloadResult   3: 2048 op, 465949300.00 ns, 227.5143 us/op
# WorkloadResult   4: 2048 op, 431471400.00 ns, 210.6794 us/op
# WorkloadResult   5: 2048 op, 528337000.00 ns, 257.9771 us/op
# WorkloadResult   6: 2048 op, 462244900.00 ns, 225.7055 us/op
# WorkloadResult   7: 2048 op, 409819600.00 ns, 200.1072 us/op
# WorkloadResult   8: 2048 op, 426075900.00 ns, 208.0449 us/op
# WorkloadResult   9: 2048 op, 558515700.00 ns, 272.7127 us/op
# WorkloadResult  10: 2048 op, 463856400.00 ns, 226.4924 us/op
# WorkloadResult  11: 2048 op, 519500700.00 ns, 253.6625 us/op
# WorkloadResult  12: 2048 op, 527820800.00 ns, 257.7250 us/op
# WorkloadResult  13: 2048 op, 545278300.00 ns, 266.2492 us/op
# WorkloadResult  14: 2048 op, 451437600.00 ns, 220.4285 us/op
# WorkloadResult  15: 2048 op, 423155400.00 ns, 206.6188 us/op
# WorkloadResult  16: 2048 op, 412305300.00 ns, 201.3209 us/op
# WorkloadResult  17: 2048 op, 414342500.00 ns, 202.3157 us/op
# WorkloadResult  18: 2048 op, 419886700.00 ns, 205.0228 us/op
# WorkloadResult  19: 2048 op, 414905900.00 ns, 202.5908 us/op
# WorkloadResult  20: 2048 op, 418287400.00 ns, 204.2419 us/op
# WorkloadResult  21: 2048 op, 394263600.00 ns, 192.5115 us/op
# WorkloadResult  22: 2048 op, 411904700.00 ns, 201.1253 us/op
# WorkloadResult  23: 2048 op, 410202000.00 ns, 200.2939 us/op
# WorkloadResult  24: 2048 op, 404524300.00 ns, 197.5216 us/op
# WorkloadResult  25: 2048 op, 430843800.00 ns, 210.3729 us/op
# WorkloadResult  26: 2048 op, 439129000.00 ns, 214.4185 us/op
# WorkloadResult  27: 2048 op, 402873500.00 ns, 196.7156 us/op
# WorkloadResult  28: 2048 op, 407088300.00 ns, 198.7736 us/op
# WorkloadResult  29: 2048 op, 411798500.00 ns, 201.0735 us/op
# WorkloadResult  30: 2048 op, 411751900.00 ns, 201.0507 us/op
# WorkloadResult  31: 2048 op, 405787200.00 ns, 198.1383 us/op
# WorkloadResult  32: 2048 op, 408633300.00 ns, 199.5280 us/op
# WorkloadResult  33: 2048 op, 402352900.00 ns, 196.4614 us/op
# WorkloadResult  34: 2048 op, 409113700.00 ns, 199.7625 us/op
# WorkloadResult  35: 2048 op, 404377200.00 ns, 197.4498 us/op
# WorkloadResult  36: 2048 op, 393372700.00 ns, 192.0765 us/op
# WorkloadResult  37: 2048 op, 405554200.00 ns, 198.0245 us/op
# WorkloadResult  38: 2048 op, 411718800.00 ns, 201.0346 us/op
# WorkloadResult  39: 2048 op, 410543100.00 ns, 200.4605 us/op
# WorkloadResult  40: 2048 op, 409394600.00 ns, 199.8997 us/op
# WorkloadResult  41: 2048 op, 427482900.00 ns, 208.7319 us/op
# WorkloadResult  42: 2048 op, 415335800.00 ns, 202.8007 us/op
# WorkloadResult  43: 2048 op, 413380500.00 ns, 201.8459 us/op
# WorkloadResult  44: 2048 op, 423759200.00 ns, 206.9137 us/op
# WorkloadResult  45: 2048 op, 417391500.00 ns, 203.8044 us/op
# WorkloadResult  46: 2048 op, 420166100.00 ns, 205.1592 us/op
# WorkloadResult  47: 2048 op, 442297900.00 ns, 215.9658 us/op
# WorkloadResult  48: 2048 op, 446883100.00 ns, 218.2046 us/op
# WorkloadResult  49: 2048 op, 447973200.00 ns, 218.7369 us/op
# WorkloadResult  50: 2048 op, 550344300.00 ns, 268.7228 us/op
# WorkloadResult  51: 2048 op, 474761800.00 ns, 231.8173 us/op
# WorkloadResult  52: 2048 op, 456270000.00 ns, 222.7881 us/op
# WorkloadResult  53: 2048 op, 457199300.00 ns, 223.2418 us/op
# WorkloadResult  54: 2048 op, 465187400.00 ns, 227.1423 us/op
# WorkloadResult  55: 2048 op, 463401700.00 ns, 226.2704 us/op
# WorkloadResult  56: 2048 op, 508817400.00 ns, 248.4460 us/op
# WorkloadResult  57: 2048 op, 487639200.00 ns, 238.1051 us/op
# WorkloadResult  58: 2048 op, 486899900.00 ns, 237.7441 us/op
# WorkloadResult  59: 2048 op, 560979300.00 ns, 273.9157 us/op
# WorkloadResult  60: 2048 op, 520388000.00 ns, 254.0957 us/op
# WorkloadResult  61: 2048 op, 452534600.00 ns, 220.9642 us/op
# WorkloadResult  62: 2048 op, 453119100.00 ns, 221.2496 us/op
# WorkloadResult  63: 2048 op, 469205300.00 ns, 229.1042 us/op
# WorkloadResult  64: 2048 op, 448281200.00 ns, 218.8873 us/op
# WorkloadResult  65: 2048 op, 454644800.00 ns, 221.9945 us/op
# WorkloadResult  66: 2048 op, 462175100.00 ns, 225.6714 us/op
# WorkloadResult  67: 2048 op, 585479900.00 ns, 285.8789 us/op
# WorkloadResult  68: 2048 op, 509888700.00 ns, 248.9691 us/op
# WorkloadResult  69: 2048 op, 599173600.00 ns, 292.5652 us/op
# WorkloadResult  70: 2048 op, 578803700.00 ns, 282.6190 us/op
# WorkloadResult  71: 2048 op, 519188700.00 ns, 253.5101 us/op
# WorkloadResult  72: 2048 op, 518143400.00 ns, 252.9997 us/op
# WorkloadResult  73: 2048 op, 504791700.00 ns, 246.4803 us/op
# WorkloadResult  74: 2048 op, 467173600.00 ns, 228.1121 us/op
# WorkloadResult  75: 2048 op, 425655600.00 ns, 207.8396 us/op
# WorkloadResult  76: 2048 op, 483172100.00 ns, 235.9239 us/op
# WorkloadResult  77: 2048 op, 455043700.00 ns, 222.1893 us/op
# WorkloadResult  78: 2048 op, 456447000.00 ns, 222.8745 us/op
# WorkloadResult  79: 2048 op, 441240600.00 ns, 215.4495 us/op
# WorkloadResult  80: 2048 op, 547374700.00 ns, 267.2728 us/op
# WorkloadResult  81: 2048 op, 496511400.00 ns, 242.4372 us/op
# WorkloadResult  82: 2048 op, 625944400.00 ns, 305.6369 us/op
# WorkloadResult  83: 2048 op, 576744400.00 ns, 281.6135 us/op
# WorkloadResult  84: 2048 op, 597037100.00 ns, 291.5220 us/op
# WorkloadResult  85: 2048 op, 528681200.00 ns, 258.1451 us/op
# WorkloadResult  86: 2048 op, 546375300.00 ns, 266.7848 us/op
# WorkloadResult  87: 2048 op, 525887200.00 ns, 256.7809 us/op
# WorkloadResult  88: 2048 op, 530096900.00 ns, 258.8364 us/op
# WorkloadResult  89: 2048 op, 524984700.00 ns, 256.3402 us/op
# WorkloadResult  90: 2048 op, 459947900.00 ns, 224.5839 us/op
# WorkloadResult  91: 2048 op, 442605400.00 ns, 216.1159 us/op
# WorkloadResult  92: 2048 op, 481327500.00 ns, 235.0232 us/op
# WorkloadResult  93: 2048 op, 488318100.00 ns, 238.4366 us/op
# WorkloadResult  94: 2048 op, 589137500.00 ns, 287.6648 us/op
# WorkloadResult  95: 2048 op, 610769300.00 ns, 298.2272 us/op
# WorkloadResult  96: 2048 op, 581887500.00 ns, 284.1248 us/op
# WorkloadResult  97: 2048 op, 497602100.00 ns, 242.9698 us/op
# WorkloadResult  98: 2048 op, 504717100.00 ns, 246.4439 us/op
# WorkloadResult  99: 2048 op, 494349900.00 ns, 241.3818 us/op
#
#
# Mean = 229.710 us, StdErr = 2.916 us (1.27%), N = 99, StdDev = 29.014 us
# Min = 192.077 us, Q1 = 203.303 us, Median = 222.875 us, Q3 = 250.984 us, Max = 305.637 us
# IQR = 47.682 us, LowerFence = 131.780 us, UpperFence = 322.507 us
# ConfidenceInterval = [219.817 us; 239.603 us] (CI 99.9%), Margin = 9.893 us (4.31% of Mean)
# Skewness = 0.74, Kurtosis = 2.53, MValue = 3
#
# // ** Remained 1 (50.0%) benchmark(s) to run. Estimated finish 2024-02-03 9:54 (0h 0m from now) **
# ]9;4;1;50\Setup power plan (GUID: 8c5e7fda-e8bf-4a96-9a85-a6e23a8c635c FriendlyName: High performance)
# // **************************
# // Benchmark: DapperBenchmarks.StoredProcedure: Job-SVIBJL(Toolchain=InProcessEmitToolchain)
# // *** Execute ***
# // Launch: 1 / 1
#
# // Benchmark Process Environment Information:
# // BenchmarkDotNet v0.13.12
# // Runtime=.NET 8.0.1 (8.0.123.58001), X64 RyuJIT AVX-512F+CD+BW+DQ+VL+VBMI
# // GC=Concurrent Server
# // HardwareIntrinsics=AVX-512F+CD+BW+DQ+VL+VBMI,AES,BMI1,BMI2,FMA,LZCNT,PCLMUL,POPCNT VectorSize=256
# // Job: Job-SVIBJL(Toolchain=InProcessEmitToolchain)
#
# OverheadJitting  1: 1 op, 383000.00 ns, 383.0000 us/op
# WorkloadJitting  1: 1 op, 98183000.00 ns, 98.1830 ms/op
#
# WorkloadPilot    1: 2 op, 12641900.00 ns, 6.3209 ms/op
# WorkloadPilot    2: 3 op, 20076700.00 ns, 6.6922 ms/op
# WorkloadPilot    3: 4 op, 25467700.00 ns, 6.3669 ms/op
# WorkloadPilot    4: 5 op, 31385500.00 ns, 6.2771 ms/op
# WorkloadPilot    5: 6 op, 32564100.00 ns, 5.4273 ms/op
# WorkloadPilot    6: 7 op, 61669100.00 ns, 8.8099 ms/op
# WorkloadPilot    7: 8 op, 22358900.00 ns, 2.7949 ms/op
# WorkloadPilot    8: 9 op, 30218500.00 ns, 3.3576 ms/op
# WorkloadPilot    9: 10 op, 45150600.00 ns, 4.5151 ms/op
# WorkloadPilot   10: 11 op, 37112500.00 ns, 3.3739 ms/op
# WorkloadPilot   11: 12 op, 35283500.00 ns, 2.9403 ms/op
# WorkloadPilot   12: 13 op, 53823000.00 ns, 4.1402 ms/op
# WorkloadPilot   13: 14 op, 46966200.00 ns, 3.3547 ms/op
# WorkloadPilot   14: 15 op, 53200600.00 ns, 3.5467 ms/op
# WorkloadPilot   15: 16 op, 48395400.00 ns, 3.0247 ms/op
# WorkloadPilot   16: 32 op, 90756800.00 ns, 2.8361 ms/op
# WorkloadPilot   17: 64 op, 188808600.00 ns, 2.9501 ms/op
# WorkloadPilot   18: 128 op, 354505800.00 ns, 2.7696 ms/op
# WorkloadPilot   19: 256 op, 699291300.00 ns, 2.7316 ms/op
#
# WorkloadWarmup   1: 256 op, 754964100.00 ns, 2.9491 ms/op
# WorkloadWarmup   2: 256 op, 1460800900.00 ns, 5.7063 ms/op
# WorkloadWarmup   3: 256 op, 726795000.00 ns, 2.8390 ms/op
# WorkloadWarmup   4: 256 op, 862223400.00 ns, 3.3681 ms/op
# WorkloadWarmup   5: 256 op, 994725400.00 ns, 3.8856 ms/op
# WorkloadWarmup   6: 256 op, 878730200.00 ns, 3.4325 ms/op
#
# WorkloadActual   1: 256 op, 688834300.00 ns, 2.6908 ms/op
# WorkloadActual   2: 256 op, 687624200.00 ns, 2.6860 ms/op
# WorkloadActual   3: 256 op, 856016000.00 ns, 3.3438 ms/op
# WorkloadActual   4: 256 op, 699288700.00 ns, 2.7316 ms/op
# WorkloadActual   5: 256 op, 783421200.00 ns, 3.0602 ms/op
# WorkloadActual   6: 256 op, 819457400.00 ns, 3.2010 ms/op
# WorkloadActual   7: 256 op, 880364400.00 ns, 3.4389 ms/op
# WorkloadActual   8: 256 op, 694086900.00 ns, 2.7113 ms/op
# WorkloadActual   9: 256 op, 656007000.00 ns, 2.5625 ms/op
# WorkloadActual  10: 256 op, 659207800.00 ns, 2.5750 ms/op
# WorkloadActual  11: 256 op, 668767000.00 ns, 2.6124 ms/op
# WorkloadActual  12: 256 op, 699130100.00 ns, 2.7310 ms/op
# WorkloadActual  13: 256 op, 716590800.00 ns, 2.7992 ms/op
# WorkloadActual  14: 256 op, 673321900.00 ns, 2.6302 ms/op
# WorkloadActual  15: 256 op, 661310100.00 ns, 2.5832 ms/op
# WorkloadActual  16: 256 op, 633444700.00 ns, 2.4744 ms/op
# WorkloadActual  17: 256 op, 649394500.00 ns, 2.5367 ms/op
# WorkloadActual  18: 256 op, 650152900.00 ns, 2.5397 ms/op
# WorkloadActual  19: 256 op, 631185900.00 ns, 2.4656 ms/op
# WorkloadActual  20: 256 op, 613397200.00 ns, 2.3961 ms/op
# WorkloadActual  21: 256 op, 662747900.00 ns, 2.5889 ms/op
# WorkloadActual  22: 256 op, 648205200.00 ns, 2.5321 ms/op
# WorkloadActual  23: 256 op, 654726900.00 ns, 2.5575 ms/op
# WorkloadActual  24: 256 op, 648540800.00 ns, 2.5334 ms/op
# WorkloadActual  25: 256 op, 697074200.00 ns, 2.7229 ms/op
# WorkloadActual  26: 256 op, 838517700.00 ns, 3.2755 ms/op
# WorkloadActual  27: 256 op, 877429800.00 ns, 3.4275 ms/op
# WorkloadActual  28: 256 op, 734815000.00 ns, 2.8704 ms/op
# WorkloadActual  29: 256 op, 702123700.00 ns, 2.7427 ms/op
# WorkloadActual  30: 256 op, 645023200.00 ns, 2.5196 ms/op
# WorkloadActual  31: 256 op, 659154700.00 ns, 2.5748 ms/op
# WorkloadActual  32: 256 op, 667510900.00 ns, 2.6075 ms/op
# WorkloadActual  33: 256 op, 685913100.00 ns, 2.6793 ms/op
# WorkloadActual  34: 256 op, 625081600.00 ns, 2.4417 ms/op
# WorkloadActual  35: 256 op, 696721600.00 ns, 2.7216 ms/op
# WorkloadActual  36: 256 op, 640769000.00 ns, 2.5030 ms/op
# WorkloadActual  37: 256 op, 662843800.00 ns, 2.5892 ms/op
# WorkloadActual  38: 256 op, 729781100.00 ns, 2.8507 ms/op
# WorkloadActual  39: 256 op, 632118500.00 ns, 2.4692 ms/op
# WorkloadActual  40: 256 op, 658570400.00 ns, 2.5725 ms/op
# WorkloadActual  41: 256 op, 908078100.00 ns, 3.5472 ms/op
# WorkloadActual  42: 256 op, 731701500.00 ns, 2.8582 ms/op
# WorkloadActual  43: 256 op, 663793700.00 ns, 2.5929 ms/op
# WorkloadActual  44: 256 op, 649209200.00 ns, 2.5360 ms/op
# WorkloadActual  45: 256 op, 652979600.00 ns, 2.5507 ms/op
# WorkloadActual  46: 256 op, 693659000.00 ns, 2.7096 ms/op
# WorkloadActual  47: 256 op, 658091700.00 ns, 2.5707 ms/op
# WorkloadActual  48: 256 op, 637133400.00 ns, 2.4888 ms/op
# WorkloadActual  49: 256 op, 652182700.00 ns, 2.5476 ms/op
# WorkloadActual  50: 256 op, 720897300.00 ns, 2.8160 ms/op
# WorkloadActual  51: 256 op, 649183600.00 ns, 2.5359 ms/op
# WorkloadActual  52: 256 op, 635350900.00 ns, 2.4818 ms/op
# WorkloadActual  53: 256 op, 716360900.00 ns, 2.7983 ms/op
# WorkloadActual  54: 256 op, 645203200.00 ns, 2.5203 ms/op
# WorkloadActual  55: 256 op, 635408600.00 ns, 2.4821 ms/op
# WorkloadActual  56: 256 op, 634295300.00 ns, 2.4777 ms/op
# WorkloadActual  57: 256 op, 675481200.00 ns, 2.6386 ms/op
# WorkloadActual  58: 256 op, 633375700.00 ns, 2.4741 ms/op
# WorkloadActual  59: 256 op, 642097700.00 ns, 2.5082 ms/op
# WorkloadActual  60: 256 op, 646491600.00 ns, 2.5254 ms/op
# WorkloadActual  61: 256 op, 660364500.00 ns, 2.5795 ms/op
# WorkloadActual  62: 256 op, 635643000.00 ns, 2.4830 ms/op
# WorkloadActual  63: 256 op, 698351100.00 ns, 2.7279 ms/op
# WorkloadActual  64: 256 op, 646327400.00 ns, 2.5247 ms/op
# WorkloadActual  65: 256 op, 658672900.00 ns, 2.5729 ms/op
# WorkloadActual  66: 256 op, 716228800.00 ns, 2.7978 ms/op
# WorkloadActual  67: 256 op, 629768100.00 ns, 2.4600 ms/op
# WorkloadActual  68: 256 op, 639317900.00 ns, 2.4973 ms/op
# WorkloadActual  69: 256 op, 624947200.00 ns, 2.4412 ms/op
# WorkloadActual  70: 256 op, 643647300.00 ns, 2.5142 ms/op
#
# WorkloadResult   1: 256 op, 688834300.00 ns, 2.6908 ms/op
# WorkloadResult   2: 256 op, 687624200.00 ns, 2.6860 ms/op
# WorkloadResult   3: 256 op, 699288700.00 ns, 2.7316 ms/op
# WorkloadResult   4: 256 op, 694086900.00 ns, 2.7113 ms/op
# WorkloadResult   5: 256 op, 656007000.00 ns, 2.5625 ms/op
# WorkloadResult   6: 256 op, 659207800.00 ns, 2.5750 ms/op
# WorkloadResult   7: 256 op, 668767000.00 ns, 2.6124 ms/op
# WorkloadResult   8: 256 op, 699130100.00 ns, 2.7310 ms/op
# WorkloadResult   9: 256 op, 716590800.00 ns, 2.7992 ms/op
# WorkloadResult  10: 256 op, 673321900.00 ns, 2.6302 ms/op
# WorkloadResult  11: 256 op, 661310100.00 ns, 2.5832 ms/op
# WorkloadResult  12: 256 op, 633444700.00 ns, 2.4744 ms/op
# WorkloadResult  13: 256 op, 649394500.00 ns, 2.5367 ms/op
# WorkloadResult  14: 256 op, 650152900.00 ns, 2.5397 ms/op
# WorkloadResult  15: 256 op, 631185900.00 ns, 2.4656 ms/op
# WorkloadResult  16: 256 op, 613397200.00 ns, 2.3961 ms/op
# WorkloadResult  17: 256 op, 662747900.00 ns, 2.5889 ms/op
# WorkloadResult  18: 256 op, 648205200.00 ns, 2.5321 ms/op
# WorkloadResult  19: 256 op, 654726900.00 ns, 2.5575 ms/op
# WorkloadResult  20: 256 op, 648540800.00 ns, 2.5334 ms/op
# WorkloadResult  21: 256 op, 697074200.00 ns, 2.7229 ms/op
# WorkloadResult  22: 256 op, 734815000.00 ns, 2.8704 ms/op
# WorkloadResult  23: 256 op, 702123700.00 ns, 2.7427 ms/op
# WorkloadResult  24: 256 op, 645023200.00 ns, 2.5196 ms/op
# WorkloadResult  25: 256 op, 659154700.00 ns, 2.5748 ms/op
# WorkloadResult  26: 256 op, 667510900.00 ns, 2.6075 ms/op
# WorkloadResult  27: 256 op, 685913100.00 ns, 2.6793 ms/op
# WorkloadResult  28: 256 op, 625081600.00 ns, 2.4417 ms/op
# WorkloadResult  29: 256 op, 696721600.00 ns, 2.7216 ms/op
# WorkloadResult  30: 256 op, 640769000.00 ns, 2.5030 ms/op
# WorkloadResult  31: 256 op, 662843800.00 ns, 2.5892 ms/op
# WorkloadResult  32: 256 op, 729781100.00 ns, 2.8507 ms/op
# WorkloadResult  33: 256 op, 632118500.00 ns, 2.4692 ms/op
# WorkloadResult  34: 256 op, 658570400.00 ns, 2.5725 ms/op
# WorkloadResult  35: 256 op, 731701500.00 ns, 2.8582 ms/op
# WorkloadResult  36: 256 op, 663793700.00 ns, 2.5929 ms/op
# WorkloadResult  37: 256 op, 649209200.00 ns, 2.5360 ms/op
# WorkloadResult  38: 256 op, 652979600.00 ns, 2.5507 ms/op
# WorkloadResult  39: 256 op, 693659000.00 ns, 2.7096 ms/op
# WorkloadResult  40: 256 op, 658091700.00 ns, 2.5707 ms/op
# WorkloadResult  41: 256 op, 637133400.00 ns, 2.4888 ms/op
# WorkloadResult  42: 256 op, 652182700.00 ns, 2.5476 ms/op
# WorkloadResult  43: 256 op, 720897300.00 ns, 2.8160 ms/op
# WorkloadResult  44: 256 op, 649183600.00 ns, 2.5359 ms/op
# WorkloadResult  45: 256 op, 635350900.00 ns, 2.4818 ms/op
# WorkloadResult  46: 256 op, 716360900.00 ns, 2.7983 ms/op
# WorkloadResult  47: 256 op, 645203200.00 ns, 2.5203 ms/op
# WorkloadResult  48: 256 op, 635408600.00 ns, 2.4821 ms/op
# WorkloadResult  49: 256 op, 634295300.00 ns, 2.4777 ms/op
# WorkloadResult  50: 256 op, 675481200.00 ns, 2.6386 ms/op
# WorkloadResult  51: 256 op, 633375700.00 ns, 2.4741 ms/op
# WorkloadResult  52: 256 op, 642097700.00 ns, 2.5082 ms/op
# WorkloadResult  53: 256 op, 646491600.00 ns, 2.5254 ms/op
# WorkloadResult  54: 256 op, 660364500.00 ns, 2.5795 ms/op
# WorkloadResult  55: 256 op, 635643000.00 ns, 2.4830 ms/op
# WorkloadResult  56: 256 op, 698351100.00 ns, 2.7279 ms/op
# WorkloadResult  57: 256 op, 646327400.00 ns, 2.5247 ms/op
# WorkloadResult  58: 256 op, 658672900.00 ns, 2.5729 ms/op
# WorkloadResult  59: 256 op, 716228800.00 ns, 2.7978 ms/op
# WorkloadResult  60: 256 op, 629768100.00 ns, 2.4600 ms/op
# WorkloadResult  61: 256 op, 639317900.00 ns, 2.4973 ms/op
# WorkloadResult  62: 256 op, 624947200.00 ns, 2.4412 ms/op
# WorkloadResult  63: 256 op, 643647300.00 ns, 2.5142 ms/op
#
#
# Mean = 2.595 ms, StdErr = 0.015 ms (0.57%), N = 63, StdDev = 0.118 ms
# Min = 2.396 ms, Q1 = 2.511 ms, Median = 2.571 ms, Q3 = 2.688 ms, Max = 2.870 ms
# IQR = 0.177 ms, LowerFence = 2.245 ms, UpperFence = 2.954 ms
# ConfidenceInterval = [2.544 ms; 2.647 ms] (CI 99.9%), Margin = 0.051 ms (1.98% of Mean)
# Skewness = 0.7, Kurtosis = 2.47, MValue = 2.58
#
# // ** Remained 0 (0.0%) benchmark(s) to run. Estimated finish 2024-02-03 9:54 (0h 0m from now) **
# ]9;4;1;100\Successfully reverted power plan (GUID: 381b4222-f694-41f0-9685-ff5bb260df2e FriendlyName: Balanced)
# // ***** BenchmarkRunner: Finish  *****
#
# // * Export *
#
# // * Detailed results *
# DapperBenchmarks.SqlQuery: Job-SVIBJL(Toolchain=InProcessEmitToolchain)
# Runtime = ; GC =
# Mean = 229.710 us, StdErr = 2.916 us (1.27%), N = 99, StdDev = 29.014 us
# Min = 192.077 us, Q1 = 203.303 us, Median = 222.875 us, Q3 = 250.984 us, Max = 305.637 us
# IQR = 47.682 us, LowerFence = 131.780 us, UpperFence = 322.507 us
# ConfidenceInterval = [219.817 us; 239.603 us] (CI 99.9%), Margin = 9.893 us (4.31% of Mean)
# Skewness = 0.74, Kurtosis = 2.53, MValue = 3
# -------------------- Histogram --------------------
# [183.845 us ; 195.339 us) | @@
# [195.339 us ; 211.802 us) | @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# [211.802 us ; 229.993 us) | @@@@@@@@@@@@@@@@@@@@@@@@@
# [229.993 us ; 242.405 us) | @@@@@@@
# [242.405 us ; 258.869 us) | @@@@@@@@@@@@@@@@
# [258.869 us ; 266.202 us) |
# [266.202 us ; 282.666 us) | @@@@@@@@
# [282.666 us ; 299.408 us) | @@@@@@
# [299.408 us ; 313.869 us) | @
# ---------------------------------------------------
#
# DapperBenchmarks.StoredProcedure: Job-SVIBJL(Toolchain=InProcessEmitToolchain)
# Runtime = ; GC =
# Mean = 2.595 ms, StdErr = 0.015 ms (0.57%), N = 63, StdDev = 0.118 ms
# Min = 2.396 ms, Q1 = 2.511 ms, Median = 2.571 ms, Q3 = 2.688 ms, Max = 2.870 ms
# IQR = 0.177 ms, LowerFence = 2.245 ms, UpperFence = 2.954 ms
# ConfidenceInterval = [2.544 ms; 2.647 ms] (CI 99.9%), Margin = 0.051 ms (1.98% of Mean)
# Skewness = 0.7, Kurtosis = 2.47, MValue = 2.58
# -------------------- Histogram --------------------
# [2.357 ms ; 2.439 ms) | @
# [2.439 ms ; 2.517 ms) | @@@@@@@@@@@@@@@@
# [2.517 ms ; 2.595 ms) | @@@@@@@@@@@@@@@@@@@@@@@@
# [2.595 ms ; 2.672 ms) | @@@@
# [2.672 ms ; 2.795 ms) | @@@@@@@@@@@
# [2.795 ms ; 2.873 ms) | @@@@@@@
# ---------------------------------------------------
#
# // * Summary *
#
# BenchmarkDotNet v0.13.12, Windows 11 (10.0.22631.3085/23H2/2023Update/SunValley3)
# 11th Gen Intel Core i7-11800H 2.30GHz, 1 CPU, 16 logical and 8 physical cores
# .NET SDK 8.0.101
#   [Host] : .NET 8.0.1 (8.0.123.58001), X64 RyuJIT AVX-512F+CD+BW+DQ+VL+VBMI
#
# Toolchain=InProcessEmitToolchain
#
# | Method          | Mean       | Error    | StdDev    |
# |---------------- |-----------:|---------:|----------:|
# | SqlQuery        |   229.7 us |  9.89 us |  29.01 us |
# | StoredProcedure | 2,595.5 us | 51.29 us | 117.84 us |
#
# // * Legends *
#   Mean   : Arithmetic mean of all measurements
#   Error  : Half of 99.9% confidence interval
#   StdDev : Standard deviation of all measurements
#   1 us   : 1 Microsecond (0.000001 sec)
#
# // ***** BenchmarkRunner: End *****
# Run time: 00:01:58 (118.17 sec), executed benchmarks: 2
#
# Global total time: 00:01:58 (118.64 sec), executed benchmarks: 2
# // * Artifacts cleanup *
# Artifacts cleanup is finished
# ]9;4;0;0\BenchmarkDotNet.Reports.Summary
